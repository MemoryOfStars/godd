# %% [markdown]
# 生成一个CSV文件，包含着所有的data，标注了label

# %%
import os
import pandas as pd
import numpy as np

# %%
from sklearn.utils import shuffle

# %%
pos_files = np.array(list(map(lambda x:'../positive_graph_save/' + x, os.listdir('../positive_graph_save/'))))
pos_labels = np.ones(pos_files.shape)
neg_files = np.array(list(map(lambda x:'../negative_graph_save/' + x, os.listdir('../negative_graph_save/'))))
neg_labels = np.zeros(neg_files.shape)

# %%
df_pos = pd.DataFrame([pos_files, pos_labels], index = ['file_name', 'label'])
df_neg = pd.DataFrame([neg_files, neg_labels], index = ['file_name', 'label'])

# %%
df_pos.head()
# Out:
#                                   0                            1     \
# file_name  ../positive_graph_save/3K1J  ../positive_graph_save/2P16
# label                                1                            1
#
#                                   2                            3     \
# file_name  ../positive_graph_save/1UZ1  ../positive_graph_save/3SIO
# label                                1                            1
#
#                                   4                            5     \
# file_name  ../positive_graph_save/1G3E  ../positive_graph_save/1UJ5
# label                                1                            1
#
#                                   6                            7     \
# file_name  ../positive_graph_save/5IVC  ../positive_graph_save/3DJQ
# label                                1                            1
#
#                                   8                            9     ...  \
# file_name  ../positive_graph_save/3B3S  ../positive_graph_save/4OC1  ...
# label                                1                            1  ...
#
#                                   2455                         2456  \
# file_name  ../positive_graph_save/4BI7  ../positive_graph_save/2UXI
# label                                1                            1
#
#                                   2457                         2458  \
# file_name  ../positive_graph_save/5CAS  ../positive_graph_save/5UFR
# label                                1                            1
#
#                                   2459                         2460  \
# file_name  ../positive_graph_save/4AGN  ../positive_graph_save/5OH2
# label                                1                            1
#
#                                   2461                         2462  \
# file_name  ../positive_graph_save/4MC9  ../positive_graph_save/4G0P
# label                                1                            1
#
#                                   2463                         2464
# file_name  ../positive_graph_save/2WC3  ../positive_graph_save/4GAH
# label                                1                            1
#
# [2 rows x 2465 columns]

# %%
df_neg.head()
# Out:
#                                            0     \
# file_name  ../negative_graph_save/2jdu_ligand_4
# label                                         0
#
#                                            1     \
# file_name  ../negative_graph_save/4h3g_ligand_3
# label                                         0
#
#                                            2     \
# file_name  ../negative_graph_save/2ces_ligand_2
# label                                         0
#
#                                            3     \
# file_name  ../negative_graph_save/5ljq_ligand_1
# label                                         0
#
#                                            4     \
# file_name  ../negative_graph_save/4nuc_ligand_5
# label                                         0
#
#                                            5     \
# file_name  ../negative_graph_save/2d0k_ligand_8
# label                                         0
#
#                                            6     \
# file_name  ../negative_graph_save/2oxy_ligand_9
# label                                         0
#
#                                            7     \
# file_name  ../negative_graph_save/5nxi_ligand_7
# label                                         0
#
#                                            8     \
# file_name  ../negative_graph_save/4q6e_ligand_4
# label                                         0
#
#                                            9     ...  \
# file_name  ../negative_graph_save/4j3l_ligand_4  ...
# label                                         0  ...
#
#                                            2759  \
# file_name  ../negative_graph_save/2vxn_ligand_5
# label                                         0
#
#                                            2760  \
# file_name  ../negative_graph_save/3bl1_ligand_3
# label                                         0
#
#                                            2761  \
# file_name  ../negative_graph_save/4ai5_ligand_2
# label                                         0
#
#                                            2762  \
# file_name  ../negative_graph_save/5ty9_ligand_5
# label                                         0
#
#                                            2763  \
# file_name  ../negative_graph_save/5f62_ligand_6
# label                                         0
#
#                                            2764  \
# file_name  ../negative_graph_save/4pin_ligand_4
# label                                         0
#
#                                            2765  \
# file_name  ../negative_graph_save/4o2p_ligand_8
# label                                         0
#
#                                            2766  \
# file_name  ../negative_graph_save/3iw6_ligand_6
# label                                         0
#
#                                            2767  \
# file_name  ../negative_graph_save/5boj_ligand_2
# label                                         0
#
#                                            2768
# file_name  ../negative_graph_save/1oxr_ligand_1
# label                                         0
#
# [2 rows x 2769 columns]

# %%
df_pos.to_csv('./positive_dataset.csv')
df_neg.to_csv('./negative_dataset.csv')
