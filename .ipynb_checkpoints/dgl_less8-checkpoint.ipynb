# %% [markdown]
# ### Exclude atoms farthur than 8A From Ligand

# %%
# !mkdir ../positive_graph_featureSimplified
# !mkdir ../negative_graph_featureSimplified

# %%
#negative_graph_48A:2~4A  + 4~8A
positivePDBDir = "../positive_truncated_data/"
# positiveTarDir = "../positive_graph_save8A_test/"  # used for DGL output
positiveTarDir = "../positive_graph_featureSimplified/"
negativePDBDir = "../negative_pdb/"
# negativeTarDir = "../negative_graph_48A/"  # used for DGL output
negativeTarDir = "../negative_graph_featureSimplified/"

# %%
def ligandCenter(pdbData):
    minX, minY, minZ = 99999.0, 99999.0, 99999.0
    maxX, maxY, maxZ = -99999.0, -99999.0, -99999.0
    for data in pdbData:
        if data[1] == 0:     # Ignore Protein Atoms
            continue
        minX = data[3] if data[3]<minX else minX
        minY = data[4] if data[4]<minY else minY
        minZ = data[5] if data[5]<minZ else minZ
        maxX = data[3] if data[3]>maxX else maxX
        maxY = data[4] if data[4]>maxY else maxY
        maxZ = data[5] if data[5]>maxZ else maxZ
    return minX, minY, minZ, maxX, maxY, maxZ

# %%
def fartherThan8A(ligandBox, atomPosition):
    x, y, z = atomPosition[0], atomPosition[1], atomPosition[2]
    minX, minY, minZ, maxX, maxY, maxZ = ligandBox
#     x_dis = x - minX
#     y_dis = y - minY
#     z_dis = z - minZ
#     disMin = math.sqrt(x_dis**2+y_dis**2+z_dis**2)
    
#     x_dis = x - maxX
#     y_dis = y - maxY
#     z_dis = z - maxZ
#     disMax = math.sqrt(x_dis**2+y_dis**2+z_dis**2)
    centerX, centerY, centerZ = (minX+maxX)/2, (minY+maxY)/2, (minZ+maxZ)/2
    disMin = math.sqrt((centerX-minX)**2+(centerY-minY)**2+(centerZ-minZ)**2)
    disMax = math.sqrt((centerX-maxX)**2+(centerY-maxY)**2+(centerZ-maxZ)**2)
    radius = disMin if disMin > disMax else disMax
    
    dis = math.sqrt((centerX-x)**2+(centerY-y)**2+(centerZ-z)**2)
    return (dis-radius)>8

# %%
from dgl.data import DGLDataset
import os
import numpy as np
import pandas as pd
import torch as th
import dgl
import json
import math
# Out:
# Using backend: pytorch

# %%
rmsdDf = pd.read_csv('../dock_rsmd.csv')
ligandRMSD48A = []
for i, row in rmsdDf.iterrows():
    if row[2] > 2 and row[2] <8:
        ligandRMSD48A.append(row[1])
len(ligandRMSD48A)
# Out:
# 21778

# %%
receptorPDBQTDir = '/home/kmk_gmx/Desktop/bioinfo/receptor_dock/'  # receptor Dir (file name eg:5orh.pdbqt)
ligandPDBQTDir = '/home/kmk_gmx/Desktop/bioinfo/ligand_dock/'      # ligand Dir (file name eg:5orh.pdbqt)
dockingPDBQTDir = '/data/bilab/kaku/test_dockings_splited/'              # docking Dir (file name eg:5orh_ligand_3.pdbqt)
dockingPDBQTDir = '/home/kmk_gmx/Desktop/bioinfo/dockings/'
receptorPDBQTFiles = [i for i in os.listdir(receptorPDBQTDir)]
ligandPDBQTFiles = [i for i in os.listdir(ligandPDBQTDir)]
#dockingPDBQTFiles = os.listdir('/home/kmk_gmx/Desktop/bioinfo/negative_pdb/')
#dockingPDBQTFiles = os.listdir(dockingPDBQTDir)   # docking file name list(used in `getAllDocks()`)
dockingPDBQTFiles = []
for f in ligandRMSD48A:
    dockingPDBQTFiles.append(f + '.pdbqt')
len(dockingPDBQTFiles)
# Out:
# 21778

# %%
def extractAtomLines(pdbqtLines):
    atomLines = []
    for line in pdbqtLines:
        l = line.strip()
        if l[:4] != 'ATOM':
            continue
        pdbqtCols = []
        pdbqtCols.append(l[0:6].strip())
        pdbqtCols.append(l[6:11].strip())
        pdbqtCols.append(l[12:16].strip())
        pdbqtCols.append(l[16:17].strip())
        pdbqtCols.append(l[17:21].strip())
        pdbqtCols.append(l[21:22].strip())
        pdbqtCols.append(l[22:26].strip())
        pdbqtCols.append(l[26:27].strip())
        pdbqtCols.append(l[30:38].strip())
        pdbqtCols.append(l[38:46].strip())
        pdbqtCols.append(l[46:54].strip())
        pdbqtCols.append(l[54:60].strip())
        pdbqtCols.append(l[60:66].strip())
        pdbqtCols.append(l[66:76].strip())
        pdbqtCols.append(l[76:].strip())
        if pdbqtCols[PDBQT_TYPE_INDEX].upper() not in ELEMENT_TYPE:
            continue
        atomLines.append(pdbqtCols)
    return atomLines

# %%
def getAllDocks(recepName):
    docks = []
    dockNames = []
    for dockFileName in dockingPDBQTFiles:
        if recepName in dockFileName:
            dockFile = open(dockingPDBQTDir + dockFileName + 'qt')
            dockLines = extractAtomLines(dockFile.readlines())
            docks.append(dockLines)
            dockNames.append(dockFileName[:-4])
    return docks, dockNames

# %%
# specified for test dataset
def getAllTestDocks(recepName):
    docks = []
    dockNames = []
    for dockFileName in dockingPDBQTFiles:
        if recepName in dockFileName:
            dockFile = open(dockingPDBQTDir + dockFileName)
            dockLines = extractAtomLines(dockFile.readlines())
            docks.append(dockLines)
            dockNames.append(dockFileName[:-6])
    return docks, dockNames

# %%
PDBQT_X_POS_INDEX = 8
PDBQT_Y_POS_INDEX = 9
PDBQT_Z_POS_INDEX = 10
PDBQT_TYPE_INDEX  = 14
ELEMENT_TYPE = ['HD', 'C', 'A', 'N', 'NA', 'OA', 'F', 'MG', 'P', 'S', 'CL', 'CA', 'MN', 'FE', 'ZN', 'BR', 'I']
RECEP_ELEMENT_ONEHOT = {}
LIG_ELEMENT_ONEHOT = {}
for idx, ele in enumerate(ELEMENT_TYPE):
    RECEP_ELEMENT_ONEHOT[ele] = [0]*len(ELEMENT_TYPE)*2
    RECEP_ELEMENT_ONEHOT[ele][idx] = 1
for idx, ele in enumerate(ELEMENT_TYPE):
    LIG_ELEMENT_ONEHOT[ele] = [0]*len(ELEMENT_TYPE)*2
    LIG_ELEMENT_ONEHOT[ele][idx+len(ELEMENT_TYPE)] = 1

# %%
s = '      '
s.strip()
# Out:
# ''

# %%
def distanceIn2Atoms(atom1, atom2):
    atom1x = float(atom1[PDBQT_X_POS_INDEX])
    atom1y = float(atom1[PDBQT_Y_POS_INDEX])
    atom1z = float(atom1[PDBQT_Z_POS_INDEX])
    atom2x = float(atom2[PDBQT_X_POS_INDEX])
    atom2y = float(atom2[PDBQT_Y_POS_INDEX])
    atom2z = float(atom2[PDBQT_Z_POS_INDEX])
    return math.sqrt((atom1x-atom2x)**2 + (atom1y-atom2y)**2 + (atom1z-atom2z)**2)

# %%
def distancesFromLigand(atom, ligand):
    atomx = float(atom[PDBQT_X_POS_INDEX])
    atomy = float(atom[PDBQT_Y_POS_INDEX])
    atomz = float(atom[PDBQT_Z_POS_INDEX])
    distances = []
    for a in ligand:
        ax = float(a[PDBQT_X_POS_INDEX])
        ay = float(a[PDBQT_Y_POS_INDEX])
        az = float(a[PDBQT_Z_POS_INDEX])
        dist = math.sqrt((atomx-ax)**2 + (atomy-ay)**2 + (atomz-az)**2)
        distances.append(dist)
    return distances

# %%
def minDisFromLigand(atom, ligand):
    distances = distancesFromLigand(atom, ligand)
    return min(distances)

# %%
a = [1,2,3,4,5]
b = [8,7,8,5]
a = [i+1 for i in a]
a
# Out:
# [2, 3, 4, 5, 6]

# %%
def generateDGL(receptor, ligand, name):
    u_set = []
    v_set = []
    graph_ndata = []
    graph_edata = [] #edge weights
    for atom in receptor:
        if atom[PDBQT_TYPE_INDEX].upper() not in RECEP_ELEMENT_ONEHOT:
            print(atom[PDBQT_TYPE_INDEX])
        #print(atom)
        graph_ndata.append([RECEP_ELEMENT_ONEHOT[atom[PDBQT_TYPE_INDEX].upper()]])
    for atom in ligand:
        if atom[PDBQT_TYPE_INDEX].upper() not in RECEP_ELEMENT_ONEHOT:
            print(atom[PDBQT_TYPE_INDEX])
        graph_ndata.append([LIG_ELEMENT_ONEHOT[atom[PDBQT_TYPE_INDEX].upper()]]) 
        
    for i, atomI in enumerate(receptor + ligand):
        ligI  = False if i < len(receptor) else True  # whether it's a ligand atom
        for j, atomJ in enumerate(receptor + ligand):
            ligJ  = False if j < len(receptor) else True
            dis = distanceIn2Atoms(atomI, atomJ)
            if dis < 2.0 and ligI == ligJ:
                graph_edata.append([1])
                u_set.append(i)
                v_set.append(j)
            elif dis < 5.0 and ligI != ligJ:
                graph_edata.append([dis])
                u_set.append(i)
                v_set.append(j)
    g = dgl.DGLGraph()
    g.add_nodes(len(graph_ndata))
    g.add_edges(u_set, v_set)
    print(name, len(graph_ndata), len(graph_edata), len(graph_ndata), len(u_set), len(v_set))
    g.edata['h'] = th.tensor(graph_edata)
    g.ndata['h'] = th.tensor(graph_ndata)

    dgl.save_graphs(name, [g])

# %%
def generatePosiDGL(recep, lig, name):
    recepAtomIn8 = []
    for atom in recep:
        if minDisFromLigand(atom, lig) > 8:
            continue
        recepAtomIn8.append(atom)
    generateDGL(recepAtomIn8, lig, positiveTarDir + name)

# %%
def generateNegaDGL(recep, docks, dockNames):
    if len(docks) == 0:
        return
    for i, dock in enumerate(docks):
        recepAtomIn8 = []
        for atom in recep:
            if minDisFromLigand(atom, dock)>8:
                continue
            recepAtomIn8.append(atom)
        generateDGL(recepAtomIn8, dock, negativeTarDir + dockNames[i])

# %%
# generate test dataset
for name in os.listdir(receptorPDBQTDir):
    recepFile = open(receptorPDBQTDir + name)
    ligFile   = open(ligandPDBQTDir + name)
    recep = extractAtomLines(recepFile.readlines())
    lig   = extractAtomLines(ligFile.readlines())
    #docks, dockNames = getAllTestDocks(name[:4])

    generatePosiDGL(recep, lig, name[:4])
    #generateNegaDGL(recep, docks, dockNames)
    
    # print(name[:4], len(docks))
    ligFile.close()
    recepFile.close()
# Out:
# ../positive_graph_featureSimplified/6dil 505 3057 505 3057 3057
# ../positive_graph_featureSimplified/3d8z 242 1508 242 1508 1508
# ../positive_graph_featureSimplified/3el5 551 3321 551 3321 3321
# ../positive_graph_featureSimplified/6gl9 390 2280 390 2280 2280
# ../positive_graph_featureSimplified/4ahs 266 1424 266 1424 1424
# ../positive_graph_featureSimplified/5lvq 251 1385 251 1385 1385
# ../positive_graph_featureSimplified/3c4h 252 1386 252 1386 1386
# ../positive_graph_featureSimplified/3cdb 488 2714 488 2714 2714
# ../positive_graph_featureSimplified/5aoj 264 1386 264 1386 1386
# ../positive_graph_featureSimplified/5e2l 290 1452 290 1452 1452
# ../positive_graph_featureSimplified/5mnr 438 2702 438 2702 2702
# ../positive_graph_featureSimplified/3arq 430 2892 430 2892 2892
# ../positive_graph_featureSimplified/1iih 279 1615 279 1615 1615
# ../positive_graph_featureSimplified/3uod 313 1921 313 1921 1921
# ../positive_graph_featureSimplified/1fzj 766 5798 766 5798 5798
# ../positive_graph_featureSimplified/6f20 275 1405 275 1405 1405
# ../positive_graph_featureSimplified/2wzm 482 3360 482 3360 3360
# ../positive_graph_featureSimplified/3n76 478 2746 478 2746 2746
# ../positive_graph_featureSimplified/5kly 466 3228 466 3228 3228
# ../positive_graph_featureSimplified/2qd7 501 3053 501 3053 3053
# ../positive_graph_featureSimplified/5nxi 350 1890 350 1890 1890
# ../positive_graph_featureSimplified/3kjd 353 2163 353 2163 2163
# ../positive_graph_featureSimplified/5vcz 438 2562 438 2562 2562
# ../positive_graph_featureSimplified/2avm 678 4886 678 4886 4886
# ../positive_graph_featureSimplified/2pwc 523 3135 523 3135 3135
# ../positive_graph_featureSimplified/4b2l 222 1184 222 1184 1184
# ../positive_graph_featureSimplified/5j41 594 4088 594 4088 4088
# ../positive_graph_featureSimplified/2w66 353 2173 353 2173 2173
# ../positive_graph_featureSimplified/3bra 239 1167 239 1167 1167
# ../positive_graph_featureSimplified/2vuk 256 1398 256 1398 1398
# ../positive_graph_featureSimplified/6b4u 369 1997 369 1997 1997
# ../positive_graph_featureSimplified/2fqo 422 2716 422 2716 2716
# ../positive_graph_featureSimplified/4buq 292 1794 292 1794 1794
# ../positive_graph_featureSimplified/3mdz 295 1535 295 1535 1535
# ../positive_graph_featureSimplified/4cp7 550 3562 550 3562 3562
# ../positive_graph_featureSimplified/4lko 325 1871 325 1871 1871
# ../positive_graph_featureSimplified/1jeu 627 4121 627 4121 4121
# ../positive_graph_featureSimplified/5upz 571 3571 571 3571 3571
# ../positive_graph_featureSimplified/3bl1 355 1947 355 1947 1947
# ../positive_graph_featureSimplified/4jkw 216 1226 216 1226 1226
# ../positive_graph_featureSimplified/2h4n 251 1257 251 1257 1257
# ../positive_graph_featureSimplified/4wop 376 2456 376 2456 2456
# ../positive_graph_featureSimplified/6h29 290 1508 290 1508 1508
# ../positive_graph_featureSimplified/5m77 457 3453 457 3453 3453
# ../positive_graph_featureSimplified/5hjq 203 1273 203 1273 1273
# ../positive_graph_featureSimplified/2f81 541 3199 541 3199 3199
# ../positive_graph_featureSimplified/3mxd 483 3085 483 3085 3085
# ../positive_graph_featureSimplified/2qwc 419 2767 419 2767 2767
# ../positive_graph_featureSimplified/3nyx 358 1972 358 1972 1972
# ../positive_graph_featureSimplified/3t3c 498 3036 498 3036 3036
# ../positive_graph_featureSimplified/1t31 422 2818 422 2818 2818
# ../positive_graph_featureSimplified/4bah 459 2951 459 2951 2951
# ../positive_graph_featureSimplified/1pzp 271 1419 271 1419 1419
# ../positive_graph_featureSimplified/6czc 389 2753 389 2753 2753
# ../positive_graph_featureSimplified/1x8t 522 3334 522 3334 3334
# ../positive_graph_featureSimplified/4f2w 383 2333 383 2333 2333
# ../positive_graph_featureSimplified/5ihh 371 1885 371 1885 1885
# ../positive_graph_featureSimplified/3lpp 409 2667 409 2667 2667
# ../positive_graph_featureSimplified/5e28 314 1724 314 1724 1724
# ../positive_graph_featureSimplified/5os5 209 1099 209 1099 1099
# ../positive_graph_featureSimplified/5ljt 371 2143 371 2143 2143
# ../positive_graph_featureSimplified/5m7s 327 1875 327 1875 1875
# ../positive_graph_featureSimplified/5w44 325 1881 325 1881 1881
# ../positive_graph_featureSimplified/4lm0 235 1021 235 1021 1021
# ../positive_graph_featureSimplified/2zkj 429 2945 429 2945 2945
# ../positive_graph_featureSimplified/2zcr 456 2512 456 2512 2512
# ../positive_graph_featureSimplified/5cc2 271 1527 271 1527 1527
# ../positive_graph_featureSimplified/4mc9 533 3155 533 3155 3155
# ../positive_graph_featureSimplified/2boh 422 2682 422 2682 2682
# ../positive_graph_featureSimplified/5h8e 468 2868 468 2868 2868
# ../positive_graph_featureSimplified/4u0w 413 2813 413 2813 2813
# ../positive_graph_featureSimplified/1ppk 433 2613 433 2613 2613
# ../positive_graph_featureSimplified/5yyf 478 4208 478 4208 4208
# ../positive_graph_featureSimplified/2vwn 464 3128 464 3128 3128
# ../positive_graph_featureSimplified/3zze 444 2488 444 2488 2488
# ../positive_graph_featureSimplified/1okl 290 1480 290 1480 1480
# ../positive_graph_featureSimplified/5j8m 373 2181 373 2181 2181
# ../positive_graph_featureSimplified/4ivc 368 2064 368 2064 2064
# ../positive_graph_featureSimplified/4uj2 444 2634 444 2634 2634
# ../positive_graph_featureSimplified/2e7f 493 3209 493 3209 3209
# ../positive_graph_featureSimplified/4baq 462 3082 462 3082 3082
# ../positive_graph_featureSimplified/3rt8 332 2060 332 2060 2060
# ../positive_graph_featureSimplified/4ysl 406 2348 406 2348 2348
# ../positive_graph_featureSimplified/4j44 291 2199 291 2199 2199
# ../positive_graph_featureSimplified/4a7i 356 2160 356 2160 2160
# ../positive_graph_featureSimplified/3cyz 294 1188 294 1188 1188
# ../positive_graph_featureSimplified/1b05 590 3814 590 3814 3814
# ../positive_graph_featureSimplified/2wl0 566 3838 566 3838 3838
# ../positive_graph_featureSimplified/2e27 340 2084 340 2084 2084
# ../positive_graph_featureSimplified/3g0w 397 1961 397 1961 1961
# ../positive_graph_featureSimplified/1nny 538 3668 538 3668 3668
# ../positive_graph_featureSimplified/1h2t 466 3510 466 3510 3510
# ../positive_graph_featureSimplified/2e91 306 1862 306 1862 1862
# ../positive_graph_featureSimplified/3gtc 280 1576 280 1576 1576
# ../positive_graph_featureSimplified/6g9u 395 2317 395 2317 2317
# ../positive_graph_featureSimplified/4g0y 288 1878 288 1878 1878
# ../positive_graph_featureSimplified/5eei 350 1902 350 1902 1902
# ../positive_graph_featureSimplified/5i9y 456 2950 456 2950 2950
# ../positive_graph_featureSimplified/4sga 371 2369 371 2369 2369
# ../positive_graph_featureSimplified/4mhy 341 1875 341 1875 1875
# ../positive_graph_featureSimplified/4cpr 535 3477 535 3477 3477
# ../positive_graph_featureSimplified/3b3s 273 1429 273 1429 1429
# ../positive_graph_featureSimplified/2xpk 498 2916 498 2916 2916
# ../positive_graph_featureSimplified/3gc5 424 2840 424 2840 2840
# ../positive_graph_featureSimplified/2vpe 481 4123 481 4123 4123
# ../positive_graph_featureSimplified/4ury 300 1716 300 1716 1716
# ../positive_graph_featureSimplified/3g5k 426 2424 426 2424 2424
# ../positive_graph_featureSimplified/2o4j 513 2477 513 2477 2477
# ../positive_graph_featureSimplified/5x54 468 3078 468 3078 3078
# ../positive_graph_featureSimplified/1ql7 363 2271 363 2271 2271
# ../positive_graph_featureSimplified/4kp8 342 1712 342 1712 1712
# ../positive_graph_featureSimplified/6fba 263 1331 263 1331 1331
# ../positive_graph_featureSimplified/4gj2 334 1872 334 1872 1872
# ../positive_graph_featureSimplified/1jq8 429 2855 429 2855 2855
# ../positive_graph_featureSimplified/5i8g 354 2056 354 2056 2056
# ../positive_graph_featureSimplified/4crf 451 2885 451 2885 2885
# ../positive_graph_featureSimplified/3ryj 344 2002 344 2002 2002
# ../positive_graph_featureSimplified/1kug 484 3470 484 3470 3470
# ../positive_graph_featureSimplified/4gzw 440 2562 440 2562 2562
# ../positive_graph_featureSimplified/3neo 352 1972 352 1972 1972
# ../positive_graph_featureSimplified/6gfs 290 1124 290 1124 1124
# ../positive_graph_featureSimplified/3nee 350 1736 350 1736 1736
# ../positive_graph_featureSimplified/1g45 314 1672 314 1672 1672
# ../positive_graph_featureSimplified/1tcx 439 2541 439 2541 2541
# ../positive_graph_featureSimplified/3wzn 365 1955 365 1955 1955
# ../positive_graph_featureSimplified/5lvl 283 1479 283 1479 1479
# ../positive_graph_featureSimplified/5v0n 585 3831 585 3831 3831
# ../positive_graph_featureSimplified/1r9l 269 1247 269 1247 1247
# ../positive_graph_featureSimplified/3hp9 276 1604 276 1604 1604
# ../positive_graph_featureSimplified/5vc3 401 2397 401 2397 2397
# ../positive_graph_featureSimplified/4ara 392 2222 392 2222 2222
# ../positive_graph_featureSimplified/4rwj 446 2330 446 2330 2330
# ../positive_graph_featureSimplified/5jss 424 2512 424 2512 2512
# ../positive_graph_featureSimplified/4q4q 372 2316 372 2316 2316
# ../positive_graph_featureSimplified/1bnu 317 1643 317 1643 1643
# ../positive_graph_featureSimplified/2zgx 400 2754 400 2754 2754
# ../positive_graph_featureSimplified/4ht2 392 2198 392 2198 2198
# ../positive_graph_featureSimplified/1tx7 269 1721 269 1721 1721
# ../positive_graph_featureSimplified/3zqe 216 978 216 978 978
# ../positive_graph_featureSimplified/4p3h 248 1050 248 1050 1050
# ../positive_graph_featureSimplified/3ekp 506 3168 506 3168 3168
# ../positive_graph_featureSimplified/4rww 485 3519 485 3519 3519
# ../positive_graph_featureSimplified/4dld 398 2530 398 2530 2530
# ../positive_graph_featureSimplified/4mrz 238 1160 238 1160 1160
# ../positive_graph_featureSimplified/1ppl 468 2784 468 2784 2784
# ../positive_graph_featureSimplified/5uff 332 2248 332 2248 2248
# ../positive_graph_featureSimplified/5e73 288 1570 288 1570 1570
# ../positive_graph_featureSimplified/3eqr 453 2741 453 2741 2741
# ../positive_graph_featureSimplified/1ta6 408 2638 408 2638 2638
# ../positive_graph_featureSimplified/4u6c 338 1756 338 1756 1756
# ../positive_graph_featureSimplified/3r16 322 1678 322 1678 1678
# ../positive_graph_featureSimplified/1r5y 323 1961 323 1961 1961
# ../positive_graph_featureSimplified/2ydw 306 1788 306 1788 1788
# ../positive_graph_featureSimplified/4y0a 310 1922 310 1922 1922
# ../positive_graph_featureSimplified/3bl0 287 1457 287 1457 1457
# ../positive_graph_featureSimplified/2jfz 358 2192 358 2192 2192
# ../positive_graph_featureSimplified/4knm 367 1885 367 1885 1885
# ../positive_graph_featureSimplified/4mpn 325 2005 325 2005 2005
# ../positive_graph_featureSimplified/5om2 292 2040 292 2040 2040
# ../positive_graph_featureSimplified/1s5z 338 2040 338 2040 2040
# ../positive_graph_featureSimplified/3bkl 552 3474 552 3474 3474
# ../positive_graph_featureSimplified/5o58 642 4658 642 4658 4658
# ../positive_graph_featureSimplified/5lwd 400 2272 400 2272 2272
# ../positive_graph_featureSimplified/5kej 335 2001 335 2001 2001
# ../positive_graph_featureSimplified/4i5c 388 2328 388 2328 2328
# ../positive_graph_featureSimplified/3bvb 536 3128 536 3128 3128
# ../positive_graph_featureSimplified/3rbu 374 2022 374 2022 2022
# ../positive_graph_featureSimplified/3cow 537 3389 537 3389 3389
# ../positive_graph_featureSimplified/6exj 351 2643 351 2643 2643
# ../positive_graph_featureSimplified/5exl 469 3213 469 3213 3213
# ../positive_graph_featureSimplified/5sz6 324 1826 324 1826 1826
# ../positive_graph_featureSimplified/5j27 431 2533 431 2533 2533
# ../positive_graph_featureSimplified/2yhw 396 2488 396 2488 2488
# ../positive_graph_featureSimplified/1w3k 418 2854 418 2854 2854
# ../positive_graph_featureSimplified/2qe4 350 1678 350 1678 1678
# ../positive_graph_featureSimplified/4v24 510 2530 510 2530 2530
# ../positive_graph_featureSimplified/3r4m 340 2046 340 2046 2046
# ../positive_graph_featureSimplified/4ufj 289 1721 289 1721 1721
# ../positive_graph_featureSimplified/3d0b 479 2795 479 2795 2795
# ../positive_graph_featureSimplified/6h33 352 1800 352 1800 1800
# ../positive_graph_featureSimplified/3t08 376 2204 376 2204 2204
# ../positive_graph_featureSimplified/2h21 389 2601 389 2601 2601
# ../positive_graph_featureSimplified/4oc0 537 3339 537 3339 3339
# ../positive_graph_featureSimplified/4rfc 300 1476 300 1476 1476
# ../positive_graph_featureSimplified/6b96 426 2472 426 2472 2472
# ../positive_graph_featureSimplified/3a6t 378 2302 378 2302 2302
# ../positive_graph_featureSimplified/3i7e 458 2686 458 2686 2686
# ../positive_graph_featureSimplified/1lke 394 2094 394 2094 2094
# ../positive_graph_featureSimplified/4x48 459 2507 459 2507 2507
# ../positive_graph_featureSimplified/6chp 439 2511 439 2511 2511
# ../positive_graph_featureSimplified/1owe 359 2385 359 2385 2385
# ../positive_graph_featureSimplified/1sqo 314 2148 314 2148 2148
# ../positive_graph_featureSimplified/5jy3 410 2288 410 2288 2288
# ../positive_graph_featureSimplified/4ase 483 2615 483 2615 2615
# ../positive_graph_featureSimplified/6dh1 528 3244 528 3244 3244
# ../positive_graph_featureSimplified/3sfg 310 1720 310 1720 1720
# ../positive_graph_featureSimplified/5m23 507 3111 507 3111 3111
# ../positive_graph_featureSimplified/3kdm 311 1647 311 1647 1647
# ../positive_graph_featureSimplified/4ew3 404 2604 404 2604 2604
# ../positive_graph_featureSimplified/5ldp 358 2298 358 2298 2298
# ../positive_graph_featureSimplified/6dj2 556 3660 556 3660 3660
# ../positive_graph_featureSimplified/1jet 595 3951 595 3951 3951
# ../positive_graph_featureSimplified/5nlk 372 2610 372 2610 2610
# ../positive_graph_featureSimplified/5iwg 399 2389 399 2389 2389
# ../positive_graph_featureSimplified/2vpo 316 1682 316 1682 1682
# ../positive_graph_featureSimplified/4uye 279 1599 279 1599 1599
# ../positive_graph_featureSimplified/3kiv 231 1327 231 1327 1327
# ../positive_graph_featureSimplified/6hai 670 3730 670 3730 3730
# ../positive_graph_featureSimplified/4gg7 427 2361 427 2361 2361
# ../positive_graph_featureSimplified/1fkh 317 1913 317 1913 1913
# ../positive_graph_featureSimplified/5ahw 327 2137 327 2137 2137
# ../positive_graph_featureSimplified/2h3e 431 2733 431 2733 2733
# ../positive_graph_featureSimplified/5l9g 504 3304 504 3304 3304
# ../positive_graph_featureSimplified/3d6p 299 2071 299 2071 2071
# ../positive_graph_featureSimplified/3lzu 456 2712 456 2712 2712
# ../positive_graph_featureSimplified/1s19 510 2398 510 2398 2398
# ../positive_graph_featureSimplified/2w26 371 2201 371 2201 2201
# ../positive_graph_featureSimplified/2pq9 514 3438 514 3438 3438
# ../positive_graph_featureSimplified/2o8h 361 1959 361 1959 1959
# ../positive_graph_featureSimplified/2ovy 387 2149 387 2149 2149
# ../positive_graph_featureSimplified/1fcy 481 2331 481 2331 2331
# ../positive_graph_featureSimplified/3qox 450 3058 450 3058 3058
# ../positive_graph_featureSimplified/2i4v 526 3166 526 3166 3166
# ../positive_graph_featureSimplified/4ef6 322 1722 322 1722 1722
# ../positive_graph_featureSimplified/1e6q 396 2434 396 2434 2434
# ../positive_graph_featureSimplified/3uev 286 1176 286 1176 1176
# ../positive_graph_featureSimplified/1f0r 365 2219 365 2219 2219
# ../positive_graph_featureSimplified/1q54 395 2269 395 2269 2269
# ../positive_graph_featureSimplified/2j47 384 2428 384 2428 2428
# ../positive_graph_featureSimplified/4xt2 431 2209 431 2209 2209
# ../positive_graph_featureSimplified/1ctt 367 2091 367 2091 2091
# ../positive_graph_featureSimplified/3g2z 284 1754 284 1754 1754
# ../positive_graph_featureSimplified/3hku 369 2135 369 2135 2135
# ../positive_graph_featureSimplified/3l0v 303 1765 303 1765 1765
# ../positive_graph_featureSimplified/4nxu 429 2693 429 2693 2693
# ../positive_graph_featureSimplified/2g5u 316 1430 316 1430 1430
# ../positive_graph_featureSimplified/6cdp 447 2691 447 2691 2691
# ../positive_graph_featureSimplified/4qgi 538 3598 538 3598 3598
# ../positive_graph_featureSimplified/4do5 336 2116 336 2116 2116
# ../positive_graph_featureSimplified/1y0l 317 1667 317 1667 1667
# ../positive_graph_featureSimplified/5y8y 275 1475 275 1475 1475
# ../positive_graph_featureSimplified/1ezq 438 2940 438 2940 2940
# ../positive_graph_featureSimplified/3nuo 547 3249 547 3249 3249
# ../positive_graph_featureSimplified/1enu 342 2054 342 2054 2054
# ../positive_graph_featureSimplified/3upk 581 3999 581 3999 3999
# ../positive_graph_featureSimplified/2wc4 447 2803 447 2803 2803
# ../positive_graph_featureSimplified/1lst 395 2335 395 2335 2335
# ../positive_graph_featureSimplified/3lpk 574 3798 574 3798 3798
# ../positive_graph_featureSimplified/4oma 410 2492 410 2492 2492
# ../positive_graph_featureSimplified/4x50 357 2305 357 2305 2305
# ../positive_graph_featureSimplified/2vh6 388 2336 388 2336 2336
# ../positive_graph_featureSimplified/5uk8 360 1886 360 1886 1886
# ../positive_graph_featureSimplified/4cwo 404 2306 404 2306 2306
# ../positive_graph_featureSimplified/4uc5 309 1633 309 1633 1633
# ../positive_graph_featureSimplified/1nki 254 1336 254 1336 1336
# ../positive_graph_featureSimplified/4zgk 278 1548 278 1548 1548
# ../positive_graph_featureSimplified/3gbe 366 2294 366 2294 2294
# ../positive_graph_featureSimplified/4fk6 347 2103 347 2103 2103
# ../positive_graph_featureSimplified/4qgd 254 1312 254 1312 1312
# ../positive_graph_featureSimplified/4dsu 177 905 177 905 905
# ../positive_graph_featureSimplified/4ibb 286 1478 286 1478 1478
# ../positive_graph_featureSimplified/2ptz 362 2166 362 2166 2166
# ../positive_graph_featureSimplified/4qxo 337 1869 337 1869 1869
# ../positive_graph_featureSimplified/2fu8 269 1387 269 1387 1387
# ../positive_graph_featureSimplified/5fpk 374 2660 374 2660 2660
# ../positive_graph_featureSimplified/2jdp 224 1358 224 1358 1358
# ../positive_graph_featureSimplified/6hlx 455 2831 455 2831 2831
# ../positive_graph_featureSimplified/5j6n 471 2797 471 2797 2797
# ../positive_graph_featureSimplified/4rqv 293 1523 293 1523 1523
# ../positive_graph_featureSimplified/3f19 333 1969 333 1969 1969
# ../positive_graph_featureSimplified/4bf1 346 2006 346 2006 2006
# ../positive_graph_featureSimplified/4gzp 365 2003 365 2003 2003
# ../positive_graph_featureSimplified/3zyu 322 1716 322 1716 1716
# ../positive_graph_featureSimplified/3cyw 536 3230 536 3230 3230
# ../positive_graph_featureSimplified/1wc1 479 3033 479 3033 3033
# ../positive_graph_featureSimplified/3utu 483 3537 483 3537 3537
# ../positive_graph_featureSimplified/3h89 470 3020 470 3020 3020
# ../positive_graph_featureSimplified/2wec 500 2996 500 2996 2996
# ../positive_graph_featureSimplified/4knn 378 2160 378 2160 2160
# ../positive_graph_featureSimplified/2qi7 468 2760 468 2760 2760
# ../positive_graph_featureSimplified/1owh 357 2389 357 2389 2389
# ../positive_graph_featureSimplified/1mq5 427 2727 427 2727 2727
# ../positive_graph_featureSimplified/3bv9 507 3659 507 3659 3659
# ../positive_graph_featureSimplified/4xoc 338 2062 338 2062 2062
# ../positive_graph_featureSimplified/2amt 457 2791 457 2791 2791
# ../positive_graph_featureSimplified/2j62 465 2777 465 2777 2777
# ../positive_graph_featureSimplified/2pvu 376 2264 376 2264 2264
# ../positive_graph_featureSimplified/5cy9 291 1623 291 1623 1623
# ../positive_graph_featureSimplified/2p95 369 2243 369 2243 2243
# ../positive_graph_featureSimplified/2uy4 266 1480 266 1480 1480
# ../positive_graph_featureSimplified/2i0a 498 3376 498 3376 3376
# ../positive_graph_featureSimplified/4b7j 409 2457 409 2457 2457
# ../positive_graph_featureSimplified/5ucj 374 2126 374 2126 2126
# ../positive_graph_featureSimplified/1oar 293 1819 293 1819 1819
# ../positive_graph_featureSimplified/3gy4 304 1960 304 1960 1960
# ../positive_graph_featureSimplified/2gv7 497 3385 497 3385 3385
# ../positive_graph_featureSimplified/3ppm 433 2327 433 2327 2327
# ../positive_graph_featureSimplified/1ft7 282 1418 282 1418 1418
# ../positive_graph_featureSimplified/5u11 366 2224 366 2224 2224
# ../positive_graph_featureSimplified/2pwr 576 3836 576 3836 3836
# ../positive_graph_featureSimplified/5z99 441 2779 441 2779 2779
# ../positive_graph_featureSimplified/2q6f 464 3104 464 3104 3104
# ../positive_graph_featureSimplified/3str 436 2630 436 2630 2630
# ../positive_graph_featureSimplified/3tsk 422 2870 422 2870 2870
# ../positive_graph_featureSimplified/1uz1 324 1886 324 1886 1886
# ../positive_graph_featureSimplified/1lbf 405 2811 405 2811 2811
# ../positive_graph_featureSimplified/5jxq 485 3177 485 3177 3177
# ../positive_graph_featureSimplified/1jvu 276 1730 276 1730 1730
# ../positive_graph_featureSimplified/1k6t 510 3210 510 3210 3210
# ../positive_graph_featureSimplified/1rr6 354 2018 354 2018 2018
# ../positive_graph_featureSimplified/2ole 381 2229 381 2229 2229
# ../positive_graph_featureSimplified/1o3i 301 2055 301 2055 2055
# ../positive_graph_featureSimplified/2jkh 433 2733 433 2733 2733
# ../positive_graph_featureSimplified/1zpa 505 3069 505 3069 3069
# ../positive_graph_featureSimplified/1vzq 489 3403 489 3403 3403
# ../positive_graph_featureSimplified/2qi4 514 3132 514 3132 3132
# ../positive_graph_featureSimplified/4m0y 315 1827 315 1827 1827
# ../positive_graph_featureSimplified/4ymq 554 2818 554 2818 2818
# ../positive_graph_featureSimplified/3gqz 281 1569 281 1569 1569
# ../positive_graph_featureSimplified/5hcy 413 2415 413 2415 2415
# ../positive_graph_featureSimplified/5wxh 446 3900 446 3900 3900
# ../positive_graph_featureSimplified/5k1f 286 1526 286 1526 1526
# ../positive_graph_featureSimplified/1g7q 631 4653 631 4653 4653
# ../positive_graph_featureSimplified/6dj5 504 3126 504 3126 3126
# ../positive_graph_featureSimplified/4gny 312 1316 312 1316 1316
# ../positive_graph_featureSimplified/4c1u 529 3669 529 3669 3669
# ../positive_graph_featureSimplified/3qfd 635 4331 635 4331 4331
# ../positive_graph_featureSimplified/3iqu 653 5655 653 5655 5655
# ../positive_graph_featureSimplified/3si3 388 2512 388 2512 2512
# ../positive_graph_featureSimplified/5ot8 397 2411 397 2411 2411
# ../positive_graph_featureSimplified/5neb 326 2010 326 2010 2010
# ../positive_graph_featureSimplified/6eqx 716 5684 716 5684 5684
# ../positive_graph_featureSimplified/1vyf 404 1882 404 1882 1882
# ../positive_graph_featureSimplified/4wkb 392 2380 392 2380 2380
# ../positive_graph_featureSimplified/1uz4 326 1772 326 1772 1772
# ../positive_graph_featureSimplified/4yml 403 2407 403 2407 2407
# ../positive_graph_featureSimplified/6fni 498 2764 498 2764 2764
# ../positive_graph_featureSimplified/4ymh 461 3191 461 3191 3191
# ../positive_graph_featureSimplified/4cpt 531 3483 531 3483 3483
# ../positive_graph_featureSimplified/1ydr 348 1732 348 1732 1732
# ../positive_graph_featureSimplified/2vk2 374 2252 374 2252 2252
# ../positive_graph_featureSimplified/6guh 378 2142 378 2142 2142
# ../positive_graph_featureSimplified/5uoo 314 1714 314 1714 1714
# ../positive_graph_featureSimplified/1dar 288 2050 288 2050 2050
# ../positive_graph_featureSimplified/5cep 359 2011 359 2011 2011
# ../positive_graph_featureSimplified/3s0d 282 1290 282 1290 1290
# ../positive_graph_featureSimplified/3l3m 411 2585 411 2585 2585
# ../positive_graph_featureSimplified/5xmx 438 2070 438 2070 2070
# ../positive_graph_featureSimplified/4yo8 394 2318 394 2318 2318
# ../positive_graph_featureSimplified/4rux 302 1554 302 1554 1554
# ../positive_graph_featureSimplified/4c2v 489 2901 489 2901 2901
# ../positive_graph_featureSimplified/3ocz 512 3358 512 3358 3358
# ../positive_graph_featureSimplified/3b27 368 2070 368 2070 2070
# ../positive_graph_featureSimplified/1o3l 302 2192 302 2192 2192
# ../positive_graph_featureSimplified/6htg 305 1799 305 1799 1799
# ../positive_graph_featureSimplified/3eeb 419 3187 419 3187 3187
# ../positive_graph_featureSimplified/1ppc 372 2614 372 2614 2614
# ../positive_graph_featureSimplified/5nyh 509 3123 509 3123 3123
# ../positive_graph_featureSimplified/4qy3 280 1674 280 1674 1674
# ../positive_graph_featureSimplified/2vw2 369 2121 369 2121 2121
# ../positive_graph_featureSimplified/1azm 300 1518 300 1518 1518
# ../positive_graph_featureSimplified/5tbm 428 2342 428 2342 2342
# ../positive_graph_featureSimplified/3t09 367 2189 367 2189 2189
# ../positive_graph_featureSimplified/4mq6 462 2678 462 2678 2678
# ../positive_graph_featureSimplified/1x1z 453 2807 453 2807 2807
# ../positive_graph_featureSimplified/1jao 320 1994 320 1994 1994
# ../positive_graph_featureSimplified/1q5k 308 1700 308 1700 1700
# ../positive_graph_featureSimplified/2rio 359 1971 359 1971 1971
# ../positive_graph_featureSimplified/4nku 458 2998 458 2998 2998
# ../positive_graph_featureSimplified/2q89 291 1635 291 1635 1635
# ../positive_graph_featureSimplified/5i3v 444 2804 444 2804 2804
# ../positive_graph_featureSimplified/4ban 458 3016 458 3016 3016
# ../positive_graph_featureSimplified/1ssq 277 1525 277 1525 1525
# ../positive_graph_featureSimplified/1y1z 272 1534 272 1534 1534
# ../positive_graph_featureSimplified/5o9o 568 3884 568 3884 3884
# ../positive_graph_featureSimplified/1b3f 652 4390 652 4390 4390
# ../positive_graph_featureSimplified/3ohi 364 2224 364 2224 2224
# ../positive_graph_featureSimplified/2pow 387 2175 387 2175 2175
# ../positive_graph_featureSimplified/4y8x 504 3512 504 3512 3512
# ../positive_graph_featureSimplified/2ha2 374 1910 374 1910 1910
# ../positive_graph_featureSimplified/4oag 507 3369 507 3369 3369
# ../positive_graph_featureSimplified/3g0i 286 1398 286 1398 1398
# ../positive_graph_featureSimplified/5mks 450 3148 450 3148 3148
# ../positive_graph_featureSimplified/2glp 356 1974 356 1974 1974
# ../positive_graph_featureSimplified/2wyj 367 2099 367 2099 2099
# ../positive_graph_featureSimplified/3qfz 325 1889 325 1889 1889
# ../positive_graph_featureSimplified/3f3e 283 1503 283 1503 1503
# ../positive_graph_featureSimplified/2tmn 274 1564 274 1564 1564
# ../positive_graph_featureSimplified/4jfs 286 1658 286 1658 1658
# ../positive_graph_featureSimplified/1lpk 482 3234 482 3234 3234
# ../positive_graph_featureSimplified/4jz1 465 2981 465 2981 2981
# ../positive_graph_featureSimplified/2j75 344 2112 344 2112 2112
# ../positive_graph_featureSimplified/3iph 424 2450 424 2450 2450
# ../positive_graph_featureSimplified/2q5k 505 3255 505 3255 3255
# ../positive_graph_featureSimplified/3ckp 458 2772 458 2772 2772
# ../positive_graph_featureSimplified/4w9i 336 2014 336 2014 2014
# ../positive_graph_featureSimplified/5cp9 187 933 187 933 933
# ../positive_graph_featureSimplified/1lnm 370 1956 370 1956 1956
# ../positive_graph_featureSimplified/5e8f 339 2103 339 2103 2103
# ../positive_graph_featureSimplified/4b34 228 1254 228 1254 1254
# ../positive_graph_featureSimplified/5ka1 308 1962 308 1962 1962
# ../positive_graph_featureSimplified/1fhd 366 2356 366 2356 2356
# ../positive_graph_featureSimplified/3u90 188 878 188 878 878
# ../positive_graph_featureSimplified/1o2n 382 2898 382 2898 2898
# ../positive_graph_featureSimplified/3f68 367 2023 367 2023 2023
# ../positive_graph_featureSimplified/3qxt 435 2979 435 2979 2979
# ../positive_graph_featureSimplified/1jlr 341 2083 341 2083 2083
# ../positive_graph_featureSimplified/1xws 431 2379 431 2379 2379
# ../positive_graph_featureSimplified/3b68 474 2598 474 2598 2598
# ../positive_graph_featureSimplified/5uf0 309 1635 309 1635 1635
# ../positive_graph_featureSimplified/5tya 270 1378 270 1378 1378
# ../positive_graph_featureSimplified/3oaf 350 1988 350 1988 1988
# ../positive_graph_featureSimplified/2ccc 345 1861 345 1861 1861
# ../positive_graph_featureSimplified/2bok 443 2885 443 2885 2885
# ../positive_graph_featureSimplified/4jpx 265 1747 265 1747 1747
# ../positive_graph_featureSimplified/5fto 397 2393 397 2393 2393
# ../positive_graph_featureSimplified/6ayr 418 2460 418 2460 2460
# ../positive_graph_featureSimplified/1gfy 291 1783 291 1783 1783
# ../positive_graph_featureSimplified/3sue 380 2610 380 2610 2610
# ../positive_graph_featureSimplified/4avs 199 1037 199 1037 1037
# ../positive_graph_featureSimplified/3nik 472 3710 472 3710 3710
# ../positive_graph_featureSimplified/3gdt 404 2800 404 2800 2800
# ../positive_graph_featureSimplified/3ui7 326 1636 326 1636 1636
# ../positive_graph_featureSimplified/5oq8 340 1856 340 1856 1856
# ../positive_graph_featureSimplified/5hz5 445 2475 445 2475 2475
# ../positive_graph_featureSimplified/2jg0 534 3462 534 3462 3462
# ../positive_graph_featureSimplified/1v2w 286 1884 286 1884 1884
# ../positive_graph_featureSimplified/5os7 324 1722 324 1722 1722
# ../positive_graph_featureSimplified/5l7g 428 2186 428 2186 2186
# ../positive_graph_featureSimplified/1kav 312 1880 312 1880 1880
# ../positive_graph_featureSimplified/4pmm 442 2540 442 2540 2540
# ../positive_graph_featureSimplified/5xo7 429 2265 429 2265 2265
# ../positive_graph_featureSimplified/1ksn 427 2899 427 2899 2899
# ../positive_graph_featureSimplified/3ddg 414 2698 414 2698 2698
# ../positive_graph_featureSimplified/4zx0 405 2365 405 2365 2365
# ../positive_graph_featureSimplified/5u14 457 2959 457 2959 2959
# ../positive_graph_featureSimplified/6g3q 338 1854 338 1854 1854
# ../positive_graph_featureSimplified/5cas 399 2387 399 2387 2387
# ../positive_graph_featureSimplified/2qbw 650 5108 650 5108 5108
# ../positive_graph_featureSimplified/2vpn 302 1586 302 1586 1586
# ../positive_graph_featureSimplified/1rpj 385 2399 385 2399 2399
# ../positive_graph_featureSimplified/2e9u 343 1889 343 1889 1889
# ../positive_graph_featureSimplified/1o2o 343 2429 343 2429 2429
# ../positive_graph_featureSimplified/3b3c 307 1581 307 1581 1581
# ../positive_graph_featureSimplified/2gzl 522 3184 522 3184 3184
# ../positive_graph_featureSimplified/1ela 378 2436 378 2436 2436
# ../positive_graph_featureSimplified/4u69 349 1781 349 1781 1781
# ../positive_graph_featureSimplified/3ifl 522 4222 522 4222 4222
# ../positive_graph_featureSimplified/4zyf 409 2325 409 2325 2325
# ../positive_graph_featureSimplified/3zm9 523 2941 523 2941 2941
# ../positive_graph_featureSimplified/4cd4 480 3338 480 3338 3338
# ../positive_graph_featureSimplified/4zls 517 3261 517 3261 3261
# ../positive_graph_featureSimplified/4q1w 479 2963 479 2963 2963
# ../positive_graph_featureSimplified/4nja 235 1457 235 1457 1457
# ../positive_graph_featureSimplified/4ufk 274 1612 274 1612 1612
# ../positive_graph_featureSimplified/1m1b 276 1466 276 1466 1466
# ../positive_graph_featureSimplified/2c92 544 3808 544 3808 3808
# ../positive_graph_featureSimplified/1siv 440 2834 440 2834 2834
# ../positive_graph_featureSimplified/1h2k 297 1377 297 1377 1377
# ../positive_graph_featureSimplified/5cqu 362 1914 362 1914 1914
# ../positive_graph_featureSimplified/6d5h 396 2346 396 2346 2346
# ../positive_graph_featureSimplified/5o5a 283 1643 283 1643 1643
# ../positive_graph_featureSimplified/4rpn 289 1303 289 1303 1303
# ../positive_graph_featureSimplified/6elp 436 2546 436 2546 2546
# ../positive_graph_featureSimplified/5fhm 504 3402 504 3402 3402
# ../positive_graph_featureSimplified/4mgd 341 1589 341 1589 1589
# ../positive_graph_featureSimplified/3hub 379 2065 379 2065 2065
# ../positive_graph_featureSimplified/4zow 308 1404 308 1404 1404
# ../positive_graph_featureSimplified/4yk0 233 1189 233 1189 1189
# ../positive_graph_featureSimplified/4duh 374 2246 374 2246 2246
# ../positive_graph_featureSimplified/5tcj 298 1536 298 1536 1536
# ../positive_graph_featureSimplified/1rd4 334 1728 334 1728 1728
# ../positive_graph_featureSimplified/5mgj 258 1300 258 1300 1300
# ../positive_graph_featureSimplified/1lzq 528 3290 528 3290 3290
# ../positive_graph_featureSimplified/4u70 356 1826 356 1826 1826
# ../positive_graph_featureSimplified/1amk 261 1431 261 1431 1431
# ../positive_graph_featureSimplified/1ql9 345 2099 345 2099 2099
# ../positive_graph_featureSimplified/3ag9 629 3755 629 3755 3755
# ../positive_graph_featureSimplified/5zkc 381 2071 381 2071 2071
# ../positive_graph_featureSimplified/1w3l 502 4034 502 4034 4034
# ../positive_graph_featureSimplified/3rz8 359 2063 359 2063 2063
# ../positive_graph_featureSimplified/3k4d 346 2044 346 2044 2044
# ../positive_graph_featureSimplified/4oks 358 2022 358 2022 2022
# ../positive_graph_featureSimplified/4r4t 380 2378 380 2378 2378
# ../positive_graph_featureSimplified/3lmk 296 1730 296 1730 1730
# ../positive_graph_featureSimplified/4gbd 405 2315 405 2315 2315
# ../positive_graph_featureSimplified/4loi 595 4671 595 4671 4671
# ../positive_graph_featureSimplified/4ayu 230 1308 230 1308 1308
# ../positive_graph_featureSimplified/2xjj 410 2486 410 2486 2486
# ../positive_graph_featureSimplified/3zsy 290 1660 290 1660 1660
# ../positive_graph_featureSimplified/5ikb 346 1990 346 1990 1990
# ../positive_graph_featureSimplified/2nmz 567 3749 567 3749 3749
# ../positive_graph_featureSimplified/4myd 379 2233 379 2233 2233
# ../positive_graph_featureSimplified/6eqw 667 5131 667 5131 5131
# ../positive_graph_featureSimplified/4ggz 378 2044 378 2044 2044
# ../positive_graph_featureSimplified/6el5 460 2766 460 2766 2766
# ../positive_graph_featureSimplified/4m8e 400 1848 400 1848 1848
# ../positive_graph_featureSimplified/4djo 510 3120 510 3120 3120
# ../positive_graph_featureSimplified/3rz5 338 1862 338 1862 1862
# ../positive_graph_featureSimplified/4q7s 233 1197 233 1197 1197
# ../positive_graph_featureSimplified/5nk9 428 2492 428 2492 2492
# ../positive_graph_featureSimplified/1xkk 484 2882 484 2882 2882
# ../positive_graph_featureSimplified/5nap 432 2376 432 2376 2376
# ../positive_graph_featureSimplified/3f17 326 1880 326 1880 1880
# ../positive_graph_featureSimplified/5ect 448 3170 448 3170 3170
# ../positive_graph_featureSimplified/1xh4 528 3588 528 3588 3588
# ../positive_graph_featureSimplified/1kv5 292 1586 292 1586 1586
# ../positive_graph_featureSimplified/4n6g 150 904 150 904 904
# ../positive_graph_featureSimplified/1sdv 552 3634 552 3634 3634
# ../positive_graph_featureSimplified/4dkq 366 2220 366 2220 2220
# ../positive_graph_featureSimplified/1pgp 332 2000 332 2000 2000
# ../positive_graph_featureSimplified/1i9p 339 1773 339 1773 1773
# ../positive_graph_featureSimplified/1o35 331 2453 331 2453 2453
# ../positive_graph_featureSimplified/5ta4 373 2377 373 2377 2377
# ../positive_graph_featureSimplified/4mjp 255 1375 255 1375 1375
# ../positive_graph_featureSimplified/1ydb 274 1444 274 1444 1444
# ../positive_graph_featureSimplified/2cbj 351 2233 351 2233 2233
# ../positive_graph_featureSimplified/1h6h 332 2656 332 2656 2656
# ../positive_graph_featureSimplified/3bpc 347 2433 347 2433 2433
# ../positive_graph_featureSimplified/6f9u 495 2705 495 2705 2705
# ../positive_graph_featureSimplified/1tq4 426 3076 426 3076 3076
# ../positive_graph_featureSimplified/2j7b 358 2128 358 2128 2128
# ../positive_graph_featureSimplified/5ouh 315 1663 315 1663 1663
# ../positive_graph_featureSimplified/1oif 328 1852 328 1852 1852
# ../positive_graph_featureSimplified/2jiw 376 2408 376 2408 2408
# ../positive_graph_featureSimplified/5cxa 506 3400 506 3400 3400
# ../positive_graph_featureSimplified/1c5c 326 1764 326 1764 1764
# ../positive_graph_featureSimplified/3ip5 267 1459 267 1459 1459
# ../positive_graph_featureSimplified/2i2c 535 3493 535 3493 3493
# ../positive_graph_featureSimplified/2bz6 499 3385 499 3385 3385
# ../positive_graph_featureSimplified/3mi3 391 2309 391 2309 2309
# ../positive_graph_featureSimplified/4dko 328 1706 328 1706 1706
# ../positive_graph_featureSimplified/2zjw 367 2023 367 2023 2023
# ../positive_graph_featureSimplified/5os4 243 1237 243 1237 1237
# ../positive_graph_featureSimplified/3u8j 290 1562 290 1562 1562
# ../positive_graph_featureSimplified/1wn6 509 3401 509 3401 3401
# ../positive_graph_featureSimplified/1li2 215 877 215 877 877
# ../positive_graph_featureSimplified/4x5r 384 2554 384 2554 2554
# ../positive_graph_featureSimplified/2h6t 519 3335 519 3335 3335
# ../positive_graph_featureSimplified/6cpw 567 3659 567 3659 3659
# ../positive_graph_featureSimplified/4nra 252 1236 252 1236 1236
# ../positive_graph_featureSimplified/5lle 346 2004 346 2004 2004
# ../positive_graph_featureSimplified/2gss 291 1489 291 1489 1489
# ../positive_graph_featureSimplified/3pe2 384 2226 384 2226 2226
# ../positive_graph_featureSimplified/4or6 372 2630 372 2630 2630
# ../positive_graph_featureSimplified/4k6i 403 1915 403 1915 1915
# ../positive_graph_featureSimplified/5yhe 385 2437 385 2437 2437
# ../positive_graph_featureSimplified/4hy1 382 2776 382 2776 2776
# ../positive_graph_featureSimplified/2ihj 577 3947 577 3947 3947
# ../positive_graph_featureSimplified/1ecv 296 1732 296 1732 1732
# ../positive_graph_featureSimplified/4gj3 349 1929 349 1929 1929
# ../positive_graph_featureSimplified/5d2r 469 2955 469 2955 2955
# ../positive_graph_featureSimplified/6cdj 554 3498 554 3498 3498
# ../positive_graph_featureSimplified/2x8z 327 1787 327 1787 1787
# ../positive_graph_featureSimplified/3ts4 454 2926 454 2926 2926
# ../positive_graph_featureSimplified/3cj4 307 1657 307 1657 1657
# ../positive_graph_featureSimplified/1ndv 458 3036 458 3036 3036
# ../positive_graph_featureSimplified/4cig 324 2016 324 2016 2016
# ../positive_graph_featureSimplified/3o9p 601 3929 601 3929 3929
# ../positive_graph_featureSimplified/1yp9 364 2408 364 2408 2408
# ../positive_graph_featureSimplified/6ekq 317 1977 317 1977 1977
# ../positive_graph_featureSimplified/4qfl 379 2143 379 2143 2143
# ../positive_graph_featureSimplified/3ebi 442 2678 442 2678 2678
# ../positive_graph_featureSimplified/4kz3 309 1767 309 1767 1767
# ../positive_graph_featureSimplified/2uwl 376 2076 376 2076 2076
# ../positive_graph_featureSimplified/3ta0 410 2790 410 2790 2790
# ../positive_graph_featureSimplified/1ws1 362 2126 362 2126 2126
# ../positive_graph_featureSimplified/4q4o 436 2830 436 2830 2830
# ../positive_graph_featureSimplified/1str 442 2870 442 2870 2870
# ../positive_graph_featureSimplified/1flr 327 2157 327 2157 2157
# ../positive_graph_featureSimplified/6e9a 531 3241 531 3241 3241
# ../positive_graph_featureSimplified/2r75 539 3935 539 3935 3935
# ../positive_graph_featureSimplified/6f90 310 1974 310 1974 1974
# ../positive_graph_featureSimplified/3bqc 342 1852 342 1852 1852
# ../positive_graph_featureSimplified/4e4l 375 2159 375 2159 2159
# ../positive_graph_featureSimplified/5wp5 496 3280 496 3280 3280
# ../positive_graph_featureSimplified/4re2 348 2098 348 2098 2098
# ../positive_graph_featureSimplified/2yki 517 3121 517 3121 3121
# ../positive_graph_featureSimplified/4h3f 478 2926 478 2926 2926
# ../positive_graph_featureSimplified/3tvc 366 2244 366 2244 2244
# ../positive_graph_featureSimplified/4fht 313 1653 313 1653 1653
# ../positive_graph_featureSimplified/4xoe 350 2138 350 2138 2138
# ../positive_graph_featureSimplified/1b4z 639 4219 639 4219 4219
# ../positive_graph_featureSimplified/5uln 343 1879 343 1879 1879
# ../positive_graph_featureSimplified/1yc1 464 2878 464 2878 2878
# ../positive_graph_featureSimplified/1ua4 511 3007 511 3007 3007
# ../positive_graph_featureSimplified/5anv 398 2252 398 2252 2252
# ../positive_graph_featureSimplified/2uz9 304 1688 304 1688 1688
# ../positive_graph_featureSimplified/2uwp 386 2162 386 2162 2162
# ../positive_graph_featureSimplified/1yqy 406 2326 406 2326 2326
# ../positive_graph_featureSimplified/5u0f 331 1705 331 1705 1705
# ../positive_graph_featureSimplified/4qpd 402 2674 402 2674 2674
# ../positive_graph_featureSimplified/2xm2 358 2146 358 2146 2146
# ../positive_graph_featureSimplified/5f5z 346 2056 346 2056 2056
# ../positive_graph_featureSimplified/3mho 343 1849 343 1849 1849
# ../positive_graph_featureSimplified/3vjc 580 3790 580 3790 3790
# ../positive_graph_featureSimplified/4bt5 255 1229 255 1229 1229
# ../positive_graph_featureSimplified/3jrs 356 1810 356 1810 1810
# ../positive_graph_featureSimplified/3wto 328 1734 328 1734 1734
# ../positive_graph_featureSimplified/1ydk 411 2667 411 2667 2667
# ../positive_graph_featureSimplified/4yho 447 3069 447 3069 3069
# ../positive_graph_featureSimplified/2x7t 345 1691 345 1691 1691
# ../positive_graph_featureSimplified/3dx4 363 2269 363 2269 2269
# ../positive_graph_featureSimplified/1a9m 479 2991 479 2991 2991
# ../positive_graph_featureSimplified/1utj 240 1366 240 1366 1366
# ../positive_graph_featureSimplified/4e6q 350 1948 350 1948 1948
# ../positive_graph_featureSimplified/4rfr 402 2392 402 2392 2392
# ../positive_graph_featureSimplified/4b6p 446 2630 446 2630 2630
# ../positive_graph_featureSimplified/3buf 254 1264 254 1264 1264
# ../positive_graph_featureSimplified/1o5a 380 2788 380 2788 2788
# ../positive_graph_featureSimplified/4lm4 231 1101 231 1101 1101
# ../positive_graph_featureSimplified/5l4i 308 1436 308 1436 1436
# ../positive_graph_featureSimplified/5i29 331 1927 331 1927 1927
# ../positive_graph_featureSimplified/2gv6 420 2906 420 2906 2906
# ../positive_graph_featureSimplified/4avh 335 2077 335 2077 2077
# ../positive_graph_featureSimplified/4zbf 337 1787 337 1787 1787
# ../positive_graph_featureSimplified/3uri 608 3758 608 3758 3758
# ../positive_graph_featureSimplified/2b9a 311 1391 311 1391 1391
# ../positive_graph_featureSimplified/3e93 496 2894 496 2894 2894
# ../positive_graph_featureSimplified/5fck 413 2833 413 2833 2833
# ../positive_graph_featureSimplified/1o5c 414 3036 414 3036 3036
# ../positive_graph_featureSimplified/1a28 358 1640 358 1640 1640
# ../positive_graph_featureSimplified/3wtl 301 1601 301 1601 1601
# ../positive_graph_featureSimplified/4lxz 362 1964 362 1964 1964
# ../positive_graph_featureSimplified/3zpu 525 3315 525 3315 3315
# ../positive_graph_featureSimplified/4kif 238 1274 238 1274 1274
# ../positive_graph_featureSimplified/3t60 303 1747 303 1747 1747
# ../positive_graph_featureSimplified/3zps 523 3317 523 3317 3317
# ../positive_graph_featureSimplified/1nh0 581 3969 581 3969 3969
# ../positive_graph_featureSimplified/2xog 432 3198 432 3198 3198
# ../positive_graph_featureSimplified/2xn5 380 2216 380 2216 2216
# ../positive_graph_featureSimplified/1hvr 427 2477 427 2477 2477
# ../positive_graph_featureSimplified/3fuc 454 2732 454 2732 2732
# ../positive_graph_featureSimplified/3lxe 375 2021 375 2021 2021
# ../positive_graph_featureSimplified/3arx 424 2534 424 2534 2534
# ../positive_graph_featureSimplified/3nes 321 1545 321 1545 1545
# ../positive_graph_featureSimplified/5g45 286 1440 286 1440 1440
# ../positive_graph_featureSimplified/4std 370 1790 370 1790 1790
# ../positive_graph_featureSimplified/5e2k 329 1857 329 1857 1857
# ../positive_graph_featureSimplified/5oei 333 1723 333 1723 1723
# ../positive_graph_featureSimplified/2zb1 371 1933 371 1933 1933
# ../positive_graph_featureSimplified/1zfq 282 1550 282 1550 1550
# ../positive_graph_featureSimplified/5u28 303 1705 303 1705 1705
# ../positive_graph_featureSimplified/1trd 242 1370 242 1370 1370
# ../positive_graph_featureSimplified/185l 223 937 223 937 937
# ../positive_graph_featureSimplified/4nbk 294 1866 294 1866 1866
# ../positive_graph_featureSimplified/6gzm 443 2623 443 2623 2623
# ../positive_graph_featureSimplified/1b5h 614 4238 614 4238 4238
# ../positive_graph_featureSimplified/5dx4 285 1527 285 1527 1527
# ../positive_graph_featureSimplified/6f28 333 2183 333 2183 2183
# ../positive_graph_featureSimplified/1s39 284 1606 284 1606 1606
# ../positive_graph_featureSimplified/3u8k 328 1734 328 1734 1734
# ../positive_graph_featureSimplified/5acy 326 1898 326 1898 1898
# ../positive_graph_featureSimplified/4lzr 335 1911 335 1911 1911
# ../positive_graph_featureSimplified/4w97 686 4864 686 4864 4864
# ../positive_graph_featureSimplified/6std 390 1810 390 1810 1810
# ../positive_graph_featureSimplified/3wmc 336 2054 336 2054 2054
# ../positive_graph_featureSimplified/1xh5 559 3837 559 3837 3837
# ../positive_graph_featureSimplified/3p17 385 2559 385 2559 2559
# ../positive_graph_featureSimplified/1xk9 304 1790 304 1790 1790
# ../positive_graph_featureSimplified/5o1h 280 1606 280 1606 1606
# ../positive_graph_featureSimplified/5nka 391 2313 391 2313 2313
# ../positive_graph_featureSimplified/1b6k 483 3111 483 3111 3111
# ../positive_graph_featureSimplified/4euo 314 1662 314 1662 1662
# ../positive_graph_featureSimplified/2weo 270 1328 270 1328 1328
# ../positive_graph_featureSimplified/3fat 336 2048 336 2048 2048
# ../positive_graph_featureSimplified/5mmg 355 1985 355 1985 1985
# ../positive_graph_featureSimplified/1lyx 259 1387 259 1387 1387
# ../positive_graph_featureSimplified/2r9w 386 2172 386 2172 2172
# ../positive_graph_featureSimplified/1nvr 419 2469 419 2469 2469
# ../positive_graph_featureSimplified/2hkf 545 4093 545 4093 4093
# ../positive_graph_featureSimplified/4w9p 403 2557 403 2557 2557
# ../positive_graph_featureSimplified/2vvv 453 3107 453 3107 3107
# ../positive_graph_featureSimplified/4e0x 370 2244 370 2244 2244
# ../positive_graph_featureSimplified/4q7w 242 1202 242 1202 1202
# ../positive_graph_featureSimplified/2jh6 386 2194 386 2194 2194
# ../positive_graph_featureSimplified/5dgu 518 3134 518 3134 3134
# ../positive_graph_featureSimplified/2uy5 311 1919 311 1919 1919
# ../positive_graph_featureSimplified/3eko 317 1845 317 1845 1845
# ../positive_graph_featureSimplified/2oc2 553 3207 553 3207 3207
# ../positive_graph_featureSimplified/2r9x 375 2119 375 2119 2119
# ../positive_graph_featureSimplified/1phw 276 1374 276 1374 1374
# ../positive_graph_featureSimplified/1uwf 351 2147 351 2147 2147
# ../positive_graph_featureSimplified/2cbz 324 2628 324 2628 2628
# ../positive_graph_featureSimplified/4w9k 349 2205 349 2205 2205
# ../positive_graph_featureSimplified/3f8f 344 1870 344 1870 1870
# ../positive_graph_featureSimplified/4mc2 500 2924 500 2924 2924
# ../positive_graph_featureSimplified/3sha 392 2538 392 2538 2538
# ../positive_graph_featureSimplified/6faa 417 2747 417 2747 2747
# ../positive_graph_featureSimplified/4pop 373 2197 373 2197 2197
# ../positive_graph_featureSimplified/3hb4 411 2169 411 2169 2169
# ../positive_graph_featureSimplified/5sz7 347 1877 347 1877 1877
# ../positive_graph_featureSimplified/4tmn 450 2682 450 2682 2682
# ../positive_graph_featureSimplified/4oc5 624 4100 624 4100 4100
# ../positive_graph_featureSimplified/1v2n 371 2527 371 2527 2527
# ../positive_graph_featureSimplified/4wrb 298 1848 298 1848 1848
# ../positive_graph_featureSimplified/4rak 412 2154 412 2154 2154
# ../positive_graph_featureSimplified/2boj 270 1764 270 1764 1764
# ../positive_graph_featureSimplified/4a95 393 2157 393 2157 2157
# ../positive_graph_featureSimplified/5fnc 369 2009 369 2009 2009
# ../positive_graph_featureSimplified/1o1s 572 3260 572 3260 3260
# ../positive_graph_featureSimplified/1ypg 439 2669 439 2669 2669
# ../positive_graph_featureSimplified/5hcv 419 2077 419 2077 2077
# ../positive_graph_featureSimplified/4r4o 360 2108 360 2108 2108
# ../positive_graph_featureSimplified/4b3d 190 1000 190 1000 1000
# ../positive_graph_featureSimplified/3f48 224 1226 224 1226 1226
# ../positive_graph_featureSimplified/5i7y 319 1899 319 1899 1899
# ../positive_graph_featureSimplified/3b3w 282 1454 282 1454 1454
# ../positive_graph_featureSimplified/6rnt 276 1832 276 1832 1832
# ../positive_graph_featureSimplified/4elg 517 3237 517 3237 3237
# ../positive_graph_featureSimplified/1ajp 292 1456 292 1456 1456
# ../positive_graph_featureSimplified/4cg8 475 2491 475 2491 2491
# ../positive_graph_featureSimplified/5nwi 494 3278 494 3278 3278
# ../positive_graph_featureSimplified/6g38 400 2280 400 2280 2280
# ../positive_graph_featureSimplified/4oc1 570 3600 570 3600 3600
# ../positive_graph_featureSimplified/4djp 524 3084 524 3084 3084
# ../positive_graph_featureSimplified/1gno 452 2842 452 2842 2842
# ../positive_graph_featureSimplified/1w96 445 2583 445 2583 2583
# ../positive_graph_featureSimplified/3su2 433 3179 433 3179 3179
# ../positive_graph_featureSimplified/1qbq 406 2164 406 2164 2164
# ../positive_graph_featureSimplified/4w9l 348 2214 348 2214 2214
# ../positive_graph_featureSimplified/4n5d 169 1063 169 1063 1063
# ../positive_graph_featureSimplified/6dai 331 1621 331 1621 1621
# ../positive_graph_featureSimplified/2pou 386 2154 386 2154 2154
# ../positive_graph_featureSimplified/3eax 302 1546 302 1546 1546
# ../positive_graph_featureSimplified/2a5s 323 2003 323 2003 2003
# ../positive_graph_featureSimplified/3wtj 308 1568 308 1568 1568
# ../positive_graph_featureSimplified/3p5l 277 1321 277 1321 1321
# ../positive_graph_featureSimplified/5e2s 353 2255 353 2255 2255
# ../positive_graph_featureSimplified/4x5p 369 2425 369 2425 2425
# ../positive_graph_featureSimplified/3gcs 443 2581 443 2581 2581
# ../positive_graph_featureSimplified/4gr8 421 2799 421 2799 2799
# ../positive_graph_featureSimplified/3ge7 446 2872 446 2872 2872
# ../positive_graph_featureSimplified/2r23 357 2509 357 2509 2509
# ../positive_graph_featureSimplified/3umq 167 631 167 631 631
# ../positive_graph_featureSimplified/3u93 295 1825 295 1825 1825
# ../positive_graph_featureSimplified/1k4g 385 2137 385 2137 2137
# ../positive_graph_featureSimplified/2i4z 465 2381 465 2381 2381
# ../positive_graph_featureSimplified/5oha 220 1246 220 1246 1246
# ../positive_graph_featureSimplified/3pwk 309 1645 309 1645 1645
# ../positive_graph_featureSimplified/3h8b 489 3343 489 3343 3343
# ../positive_graph_featureSimplified/5edd 456 3128 456 3128 3128
# ../positive_graph_featureSimplified/1lyb 424 2494 424 2494 2494
# ../positive_graph_featureSimplified/2gsu 382 2126 382 2126 2126
# ../positive_graph_featureSimplified/3lp7 370 2358 370 2358 2358
# ../positive_graph_featureSimplified/1eld 371 2295 371 2295 2295
# ../positive_graph_featureSimplified/1hsl 343 1963 343 1963 1963
# ../positive_graph_featureSimplified/2qtg 359 2243 359 2243 2243
# ../positive_graph_featureSimplified/4s1g 442 2690 442 2690 2690
# ../positive_graph_featureSimplified/6d5j 383 2151 383 2151 2151
# ...
# ../positive_graph_featureSimplified/5hrv 259 1403 259 1403 1403
# ../positive_graph_featureSimplified/1k1o 419 2887 419 2887 2887
# ../positive_graph_featureSimplified/4z84 474 2628 474 2628 2628
# ../positive_graph_featureSimplified/5l7e 356 1756 356 1756 1756
# ../positive_graph_featureSimplified/1o5g 409 2669 409 2669 2669
# ../positive_graph_featureSimplified/4hfp 426 2470 426 2470 2470
# ../positive_graph_featureSimplified/4ibg 341 1893 341 1893 1893
# ../positive_graph_featureSimplified/3egt 507 2861 507 2861 2861
# ../positive_graph_featureSimplified/3hmp 229 1145 229 1145 1145
# ../positive_graph_featureSimplified/3n0n 343 1919 343 1919 1919
# ../positive_graph_featureSimplified/3t0d 366 2194 366 2194 2194
# ../positive_graph_featureSimplified/3q2j 309 1583 309 1583 1583
# ../positive_graph_featureSimplified/6fng 490 2912 490 2912 2912
# ../positive_graph_featureSimplified/5dqc 575 3875 575 3875 3875
# ../positive_graph_featureSimplified/5e2o 464 3144 464 3144 3144
# ../positive_graph_featureSimplified/4nh7 490 2890 490 2890 2890
# ../positive_graph_featureSimplified/4psb 351 1893 351 1893 1893
# ../positive_graph_featureSimplified/1oxr 222 1038 222 1038 1038
# ../positive_graph_featureSimplified/4h75 613 4869 613 4869 4869
# ../positive_graph_featureSimplified/5ito 415 2551 415 2551 2551
# ../positive_graph_featureSimplified/6c7q 301 1633 301 1633 1633
# ../positive_graph_featureSimplified/1g36 387 2499 387 2499 2499
# ../positive_graph_featureSimplified/5ipc 457 3165 457 3165 3165
# ../positive_graph_featureSimplified/5ayt 361 1993 361 1993 1993
# ../positive_graph_featureSimplified/1rmz 366 2268 366 2268 2268
# ../positive_graph_featureSimplified/4iic 309 1769 309 1769 1769
# ../positive_graph_featureSimplified/6gjn 436 3224 436 3224 3224
# ../positive_graph_featureSimplified/3ckb 342 2342 342 2342 2342
# ../positive_graph_featureSimplified/5eh5 308 1602 308 1602 1602
# ../positive_graph_featureSimplified/6epz 492 3172 492 3172 3172
# ../positive_graph_featureSimplified/1u1b 406 2454 406 2454 2454
# ../positive_graph_featureSimplified/5fut 399 2149 399 2149 2149
# ../positive_graph_featureSimplified/3f33 276 1240 276 1240 1240
# ../positive_graph_featureSimplified/4bj8 364 1934 364 1934 1934
# ../positive_graph_featureSimplified/4rd0 400 3066 400 3066 3066
# ../positive_graph_featureSimplified/5ula 311 1717 311 1717 1717
# ../positive_graph_featureSimplified/1pzi 302 2070 302 2070 2070
# ../positive_graph_featureSimplified/4dmw 329 1927 329 1927 1927
# ../positive_graph_featureSimplified/4riv 266 1384 266 1384 1384
# ../positive_graph_featureSimplified/2jh0 399 2353 399 2353 2353
# ../positive_graph_featureSimplified/4rrg 398 2516 398 2516 2516
# ../positive_graph_featureSimplified/4u6z 330 1640 330 1640 1640
# ../positive_graph_featureSimplified/5i7x 339 2031 339 2031 2031
# ../positive_graph_featureSimplified/3iub 445 2873 445 2873 2873
# ../positive_graph_featureSimplified/4np2 237 1535 237 1535 1535
# ../positive_graph_featureSimplified/2za0 316 1570 316 1570 1570
# ../positive_graph_featureSimplified/5wbm 308 1636 308 1636 1636
# ../positive_graph_featureSimplified/5cbr 392 2480 392 2480 2480
# ../positive_graph_featureSimplified/3acw 349 1743 349 1743 1743
# ../positive_graph_featureSimplified/5mod 255 1159 255 1159 1159
# ../positive_graph_featureSimplified/4zzz 312 1748 312 1748 1748
# ../positive_graph_featureSimplified/5yz2 319 2165 319 2165 2165
# ../positive_graph_featureSimplified/3k1j 452 2894 452 2894 2894
# ../positive_graph_featureSimplified/3fvn 333 2131 333 2131 2131
# ../positive_graph_featureSimplified/5g60 577 4301 577 4301 4301
# ../positive_graph_featureSimplified/6hqy 280 1570 280 1570 1570
# ../positive_graph_featureSimplified/2qbr 394 2262 394 2262 2262
# ../positive_graph_featureSimplified/4kz6 313 1539 313 1539 1539
# ../positive_graph_featureSimplified/3e3c 428 1982 428 1982 1982
# ../positive_graph_featureSimplified/6csr 275 1417 275 1417 1417
# ../positive_graph_featureSimplified/5za7 336 2516 336 2516 2516
# ../positive_graph_featureSimplified/4non 264 1682 264 1682 1682
# ../positive_graph_featureSimplified/2qbu 467 3087 467 3087 3087
# ../positive_graph_featureSimplified/3l4u 431 2605 431 2605 2605
# ../positive_graph_featureSimplified/2oag 528 3306 528 3306 3306
# ../positive_graph_featureSimplified/4g8n 316 1992 316 1992 1992
# ../positive_graph_featureSimplified/4e7r 482 3100 482 3100 3100
# ../positive_graph_featureSimplified/4j47 316 2370 316 2370 2370
# ../positive_graph_featureSimplified/5d45 449 2479 449 2479 2479
# ../positive_graph_featureSimplified/1lgw 232 960 232 960 960
# ../positive_graph_featureSimplified/1zsf 531 3341 531 3341 3341
# ../positive_graph_featureSimplified/4keq 223 1155 223 1155 1155
# ../positive_graph_featureSimplified/1dzk 259 1011 259 1011 1011
# ../positive_graph_featureSimplified/4r74 445 2685 445 2685 2685
# ../positive_graph_featureSimplified/3bxf 460 3220 460 3220 3220
# ../positive_graph_featureSimplified/3zt3 285 1541 285 1541 1541
# ../positive_graph_featureSimplified/4tkh 376 1794 376 1794 1794
# ../positive_graph_featureSimplified/6fv4 340 1870 340 1870 1870
# ../positive_graph_featureSimplified/3p9m 766 5962 766 5962 5962
# ../positive_graph_featureSimplified/4ovg 235 1285 235 1285 1285
# ../positive_graph_featureSimplified/3zhx 341 1993 341 1993 1993
# ../positive_graph_featureSimplified/5isz 878 5934 878 5934 5934
# ../positive_graph_featureSimplified/3uil 209 911 209 911 911
# ../positive_graph_featureSimplified/2qnq 439 2481 439 2481 2481
# ../positive_graph_featureSimplified/5ia1 348 1856 348 1856 1856
# ../positive_graph_featureSimplified/3m35 387 2661 387 2661 2661
# ../positive_graph_featureSimplified/1j37 255 1265 255 1265 1265
# ../positive_graph_featureSimplified/6cn5 512 2782 512 2782 2782
# ../positive_graph_featureSimplified/5izf 606 3686 606 3686 3686
# ../positive_graph_featureSimplified/5ndf 233 1379 233 1379 1379
# ../positive_graph_featureSimplified/4re4 316 1826 316 1826 1826
# ../positive_graph_featureSimplified/2y7x 429 2989 429 2989 2989
# ../positive_graph_featureSimplified/5nw7 419 2737 419 2737 2737
# ../positive_graph_featureSimplified/2hnx 381 1937 381 1937 1937
# ../positive_graph_featureSimplified/5i9x 458 2840 458 2840 2840
# ../positive_graph_featureSimplified/4ayp 497 3175 497 3175 3175
# ../positive_graph_featureSimplified/1xt8 303 1793 303 1793 1793
# ../positive_graph_featureSimplified/6ei5 398 2252 398 2252 2252
# ../positive_graph_featureSimplified/4mul 487 2753 487 2753 2753
# ../positive_graph_featureSimplified/3gta 301 2247 301 2247 2247
# ../positive_graph_featureSimplified/6gnp 210 850 210 850 850
# ../positive_graph_featureSimplified/1i5r 780 5028 780 5028 5028
# ../positive_graph_featureSimplified/3ai8 252 1438 252 1438 1438
# ../positive_graph_featureSimplified/1g3d 294 1968 294 1968 1968
# ../positive_graph_featureSimplified/4c52 379 1891 379 1891 1891
# ../positive_graph_featureSimplified/4u5o 313 1955 313 1955 1955
# ../positive_graph_featureSimplified/1zgi 361 2017 361 2017 2017
# ../positive_graph_featureSimplified/6gl8 463 3071 463 3071 3071
# ../positive_graph_featureSimplified/4in9 385 2615 385 2615 2615
# ../positive_graph_featureSimplified/5dgw 506 3112 506 3112 3112
# ../positive_graph_featureSimplified/4h7q 243 1095 243 1095 1095
# ../positive_graph_featureSimplified/2we3 355 2217 355 2217 2217
# ../positive_graph_featureSimplified/5jq5 402 2374 402 2374 2374
# ../positive_graph_featureSimplified/5eqp 276 1428 276 1428 1428
# ../positive_graph_featureSimplified/5v79 375 2261 375 2261 2261
# ../positive_graph_featureSimplified/1mmr 312 2060 312 2060 2060
# ../positive_graph_featureSimplified/1o38 388 2850 388 2850 2850
# ../positive_graph_featureSimplified/5g4m 266 1500 266 1500 1500
# ../positive_graph_featureSimplified/4hp0 488 3726 488 3726 3726
# ../positive_graph_featureSimplified/1t7d 362 2376 362 2376 2376
# ../positive_graph_featureSimplified/2i6b 336 1792 336 1792 1792
# ../positive_graph_featureSimplified/5ime 412 2202 412 2202 2202
# ../positive_graph_featureSimplified/5vcv 378 2276 378 2276 2276
# ../positive_graph_featureSimplified/2wbg 450 2788 450 2788 2788
# ../positive_graph_featureSimplified/3uo4 350 1958 350 1958 1958
# ../positive_graph_featureSimplified/2aqu 484 3146 484 3146 3146
# ../positive_graph_featureSimplified/2yek 354 2248 354 2248 2248
# ../positive_graph_featureSimplified/3rlb 382 2238 382 2238 2238
# ../positive_graph_featureSimplified/4k55 225 1265 225 1265 1265
# ../positive_graph_featureSimplified/1cny 325 1623 325 1623 1623
# ../positive_graph_featureSimplified/3n3g 279 1645 279 1645 1645
# ../positive_graph_featureSimplified/5mlj 336 2118 336 2118 2118
# ../positive_graph_featureSimplified/4p6x 377 1977 377 1977 1977
# ../positive_graph_featureSimplified/4km0 328 1970 328 1970 1970
# ../positive_graph_featureSimplified/2cle 356 2022 356 2022 2022
# ../positive_graph_featureSimplified/4zw6 475 2705 475 2705 2705
# ../positive_graph_featureSimplified/3hzv 345 2409 345 2409 2409
# ../positive_graph_featureSimplified/3uw5 285 2091 285 2091 2091
# ../positive_graph_featureSimplified/1txr 374 2148 374 2148 2148
# ../positive_graph_featureSimplified/5nk4 424 2468 424 2468 2468
# ../positive_graph_featureSimplified/4gii 334 1792 334 1792 1792
# ../positive_graph_featureSimplified/2i80 320 1704 320 1704 1704
# ../positive_graph_featureSimplified/4r06 403 2025 403 2025 2025
# ../positive_graph_featureSimplified/5kz0 357 1815 357 1815 1815
# ../positive_graph_featureSimplified/5laq 424 2354 424 2354 2354
# ../positive_graph_featureSimplified/5his 258 1102 258 1102 1102
# ../positive_graph_featureSimplified/5n1s 309 1741 309 1741 1741
# ../positive_graph_featureSimplified/1g74 421 2103 421 2103 2103
# ../positive_graph_featureSimplified/6gnm 324 1612 324 1612 1612
# ../positive_graph_featureSimplified/3uxl 258 1308 258 1308 1308
# ../positive_graph_featureSimplified/5uxf 565 3913 565 3913 3913
# ../positive_graph_featureSimplified/6g3a 405 2323 405 2323 2323
# ../positive_graph_featureSimplified/5ovp 395 2807 395 2807 2807
# ../positive_graph_featureSimplified/1nhu 291 1377 291 1377 1377
# ../positive_graph_featureSimplified/6bhv 498 3358 498 3358 3358
# ../positive_graph_featureSimplified/3agl 676 4698 676 4698 4698
# ../positive_graph_featureSimplified/5aoi 245 1453 245 1453 1453
# ../positive_graph_featureSimplified/5vyy 426 2462 426 2462 2462
# ../positive_graph_featureSimplified/3tza 416 2706 416 2706 2706
# ../positive_graph_featureSimplified/3d51 370 2318 370 2318 2318
# ../positive_graph_featureSimplified/2c1p 363 1907 363 1907 1907
# ../positive_graph_featureSimplified/5ta2 395 2561 395 2561 2561
# ../positive_graph_featureSimplified/2fpz 275 1729 275 1729 1729
# ../positive_graph_featureSimplified/4aqh 338 1962 338 1962 1962
# ../positive_graph_featureSimplified/4zvi 293 1581 293 1581 1581
# ../positive_graph_featureSimplified/3mmf 355 2033 355 2033 2033
# ../positive_graph_featureSimplified/4qjw 419 2389 419 2389 2389
# ../positive_graph_featureSimplified/5oa6 632 4566 632 4566 4566
# ../positive_graph_featureSimplified/3zns 370 1986 370 1986 1986
# ../positive_graph_featureSimplified/4zme 322 1852 322 1852 1852
# ../positive_graph_featureSimplified/2zx8 401 2663 401 2663 2663
# ../positive_graph_featureSimplified/2ya7 452 2984 452 2984 2984
# ../positive_graph_featureSimplified/1ado 299 1595 299 1595 1595
# ../positive_graph_featureSimplified/3nx7 331 2013 331 2013 2013
# ../positive_graph_featureSimplified/3iue 458 2996 458 2996 2996
# ../positive_graph_featureSimplified/2tpi 339 2085 339 2085 2085
# ../positive_graph_featureSimplified/1gpn 378 2088 378 2088 2088
# ../positive_graph_featureSimplified/3udd 364 2086 364 2086 2086
# ../positive_graph_featureSimplified/3d91 508 3054 508 3054 3054
# ../positive_graph_featureSimplified/3mof 241 1171 241 1171 1171
# ../positive_graph_featureSimplified/4cst 348 2218 348 2218 2218
# ../positive_graph_featureSimplified/5op5 331 1743 331 1743 1743
# ../positive_graph_featureSimplified/4bcp 373 2063 373 2063 2063
# ../positive_graph_featureSimplified/2cen 557 3661 557 3661 3661
# ../positive_graph_featureSimplified/5vgy 340 1986 340 1986 1986
# ../positive_graph_featureSimplified/4loy 444 2806 444 2806 2806
# ../positive_graph_featureSimplified/4d8z 285 1751 285 1751 1751
# ../positive_graph_featureSimplified/2ypi 225 1193 225 1193 1193
# ../positive_graph_featureSimplified/4ai5 249 1403 249 1403 1403
# ../positive_graph_featureSimplified/3n3j 375 2213 375 2213 2213
# ../positive_graph_featureSimplified/3bgb 517 3099 517 3099 3099
# ../positive_graph_featureSimplified/4pg9 661 4427 661 4427 4427
# ../positive_graph_featureSimplified/1utl 244 1320 244 1320 1320
# ../positive_graph_featureSimplified/1o5r 463 2883 463 2883 2883
# ../positive_graph_featureSimplified/3v4t 520 3318 520 3318 3318
# ../positive_graph_featureSimplified/2bqv 477 2975 477 2975 2975
# ../positive_graph_featureSimplified/4ieh 547 3647 547 3647 3647
# ../positive_graph_featureSimplified/3iog 321 1505 321 1505 1505
# ../positive_graph_featureSimplified/1x8d 223 1219 223 1219 1219
# ../positive_graph_featureSimplified/4xu0 620 4342 620 4342 4342
# ../positive_graph_featureSimplified/5etj 419 2451 419 2451 2451
# ../positive_graph_featureSimplified/1nje 383 2349 383 2349 2349
# ../positive_graph_featureSimplified/6fuh 395 2757 395 2757 2757
# ../positive_graph_featureSimplified/5fl6 318 1670 318 1670 1670
# ../positive_graph_featureSimplified/1km3 352 2186 352 2186 2186
# ../positive_graph_featureSimplified/1r1j 333 2061 333 2061 2061
# ../positive_graph_featureSimplified/1f8e 441 2947 441 2947 2947
# ../positive_graph_featureSimplified/1gjc 392 2716 392 2716 2716
# ../positive_graph_featureSimplified/2b1i 387 2855 387 2855 2855
# ../positive_graph_featureSimplified/3jzh 384 2368 384 2368 2368
# ../positive_graph_featureSimplified/3x00 453 2645 453 2645 2645
# ../positive_graph_featureSimplified/4kwg 281 1357 281 1357 1357
# ../positive_graph_featureSimplified/4xya 291 1703 291 1703 1703
# ../positive_graph_featureSimplified/6g98 396 2294 396 2294 2294
# ../positive_graph_featureSimplified/3o84 341 1983 341 1983 1983
# ../positive_graph_featureSimplified/1bdq 428 2436 428 2436 2436
# ../positive_graph_featureSimplified/2jdm 278 1818 278 1818 1818
# ../positive_graph_featureSimplified/3u8n 378 2060 378 2060 2060
# ../positive_graph_featureSimplified/5nk3 372 2038 372 2038 2038
# ../positive_graph_featureSimplified/1b38 451 2703 451 2703 2703
# ../positive_graph_featureSimplified/6edr 387 2275 387 2275 2275
# ../positive_graph_featureSimplified/2vc9 354 2126 354 2126 2126
# ../positive_graph_featureSimplified/6eq8 460 3128 460 3128 3128
# ../positive_graph_featureSimplified/2pog 343 1611 343 1611 1611
# ../positive_graph_featureSimplified/3zi0 331 1885 331 1885 1885
# ../positive_graph_featureSimplified/2uyq 317 1815 317 1815 1815
# ../positive_graph_featureSimplified/1q91 424 2960 424 2960 2960
# ../positive_graph_featureSimplified/1qan 413 2703 413 2703 2703
# ../positive_graph_featureSimplified/3s78 251 1325 251 1325 1325
# ../positive_graph_featureSimplified/1hi5 333 2159 333 2159 2159
# ../positive_graph_featureSimplified/3m96 378 2024 378 2024 2024
# ../positive_graph_featureSimplified/4gid 631 4347 631 4347 4347
# ../positive_graph_featureSimplified/2yay 483 3161 483 3161 3161
# ../positive_graph_featureSimplified/2std 370 1662 370 1662 1662
# ../positive_graph_featureSimplified/4acc 414 2384 414 2384 2384
# ../positive_graph_featureSimplified/2hzl 226 1024 226 1024 1024
# ../positive_graph_featureSimplified/3fx6 381 2111 381 2111 2111
# ../positive_graph_featureSimplified/1pkx 363 2655 363 2655 2655
# ../positive_graph_featureSimplified/3lea 357 2107 357 2107 2107
# ../positive_graph_featureSimplified/1ghz 335 2383 335 2383 2383
# ../positive_graph_featureSimplified/4dst 209 1067 209 1067 1067
# ../positive_graph_featureSimplified/2hhn 463 2977 463 2977 2977
# ../positive_graph_featureSimplified/4de2 408 2634 408 2634 2634
# ../positive_graph_featureSimplified/1nvq 432 2560 432 2560 2560
# ../positive_graph_featureSimplified/1m7y 527 3489 527 3489 3489
# ../positive_graph_featureSimplified/2ews 468 3278 468 3278 3278
# ../positive_graph_featureSimplified/1xjd 410 2454 410 2454 2454
# ../positive_graph_featureSimplified/1e1x 370 2010 370 2010 2010
# ../positive_graph_featureSimplified/3d0e 483 2955 483 2955 2955
# ../positive_graph_featureSimplified/1atl 295 1727 295 1727 1727

# %% [markdown]
# Draw protein-ligand complex

# %%
from scipy.stats import kde
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
def newLigandCenter(pdbData):
    minX, minY, minZ = 99999.0, 99999.0, 99999.0
    maxX, maxY, maxZ = -99999.0, -99999.0, -99999.0
    for data in pdbData:
        if data[1] == 0:     # Ignore Protein Atoms
            continue
        minX = data[0] if data[0]<minX else minX
        minY = data[1] if data[1]<minY else minY
        minZ = data[2] if data[2]<minZ else minZ
        maxX = data[0] if data[0]>maxX else maxX
        maxY = data[1] if data[1]>maxY else maxY
        maxZ = data[2] if data[2]>maxZ else maxZ
    return minX, minY, minZ, maxX, maxY, maxZ

# %%
def drawSphere(x, y, z, radius, ax):
    theta, phi = np.linspace(0, 2 * np.pi, 40), np.linspace(-np.pi, np.pi, 40)
    THETA, PHI = np.meshgrid(theta, phi)
    #R = np.cos(PHI**2)
    X = radius * np.sin(PHI) * np.cos(THETA) + x
    Y = radius * np.sin(PHI) * np.sin(THETA) + y
    Z = radius * np.cos(PHI) + z
    #fig = plt.figure()
    #ax = fig.add_subplot(1,1,1, projection='3d')
    ax.plot_surface(X, Y, Z, alpha=0.3, cmap='rainbow')

    #plt.show()

# %%
# !mkdir ../figs

# %%
#pdb_name = "4bb9_ligand_2.pdb"
pdb_name = "6b98_ligand_3.pdb"
pdb_data = []                        #一个pdb文件中的信息汇总
pdb_plot_data = []
# [element_name, protein_or_ligand, chain_id, x, y, z]
with open(negativePDBDir+pdb_name) as pdb_file:
    lines = pdb_file.readlines()
    flag = False
    for i, line in enumerate(lines):
        if (line[:4]=='ATOM' or line[:6]=='HETATM') and line[76:78].strip() in valid_elements:
            atom = ['C', 0, 'A', 0.0, 0.0, 0.0]#0代表蛋白质分子。 1代表ligand分子
            atom[0] = line[76:78].strip()                   #element_name
            atom[1] = 0 if line[:4]=='ATOM' else 1  #protein or ligand
            if (i > 0 and int(line[6:11]) < int(lines[i-1][6:11])) or flag:
                flag = True
                atom[1] = 1
            atom[2] = line[21]                      #chain_id
            atom[3] = float(line[30:38].strip())    #x
            atom[4] = float(line[38:46].strip())    #y
            atom[5] = float(line[46:54].strip())    #z
            pdb_data.append(atom)
            if i%5 == 0:
                pdb_plot_data.append([atom[3], atom[4], atom[5]])
ligandBox = ligandCenter(pdb_data)
minX, minY, minZ, maxX, maxY, maxZ = ligandBox
centerX, centerY, centerZ = (minX+maxX)/2, (minY+maxY)/2, (minZ+maxZ)/2
disMin = math.sqrt((centerX-minX)**2+(centerY-minY)**2+(centerZ-minZ)**2)
disMax = math.sqrt((centerX-maxX)**2+(centerY-maxY)**2+(centerZ-maxZ)**2)
radius = disMin if disMin > disMax else disMax

pdb_plot_data = np.array(pdb_plot_data)
pdb_x = np.array(pdb_plot_data[:, 0])
pdb_y = np.array(pdb_plot_data[:, 1])
pdb_z = np.array(pdb_plot_data[:, 2])
# print(pdb_data)
# print(ligandBox)
# eval_data = []
# for i in range(len(pdb_data)):
#     if fartherThan8A(ligandBox, [pdb_data[i][0], pdb_data[i][1], pdb_data[i][2]]):
#         continue
#     if i%10 == 0:
#         eval_data.append(pdb_data[i])

# eval_data = np.array(eval_data)
# eval_x = np.array(eval_data[:, 0])
# eval_y = np.array(eval_data[:, 1])
# eval_z = np.array(eval_data[:, 2])

fig = plt.figure(figsize=(20, 20), dpi=400)
ax = fig.gca(projection='3d')
ax.scatter(pdb_x, pdb_y, pdb_z, cmap=plt.cm.Spectral, linewidth=0.2)
ax.scatter(centerX, centerY, centerZ, c= 'r', s=80)
drawSphere(centerX, centerY, centerZ,radius+8,ax)

# 调整角度，第一个数字为上下，第二个数字为左右。
ax.view_init(30, 80)
plt.savefig('../figs/exclude8AAtoms.png', dpi=400)
plt.show()

# %%
f = open('/data/bilab/kaku/docking/5orh_ligand_3.pdbqt')
atom = []
for l in f.readlines():
    data = l.strip().split()
    if data[0] == 'ATOM':
        atom.append(data)
len(atom)
# Out:
# 19
