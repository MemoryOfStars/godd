# %%
import os

# %%
l1 = os.listdir('../ligand_dock/')
l2 = os.listdir('../refined-set/')

l1 = [l[:-6] for l in l1]
l1
# Out:
# ['6dil',
#  '3d8z',
#  '3el5',
#  '6gl9',
#  '4ahs',
#  '5lvq',
#  '3c4h',
#  '3cdb',
#  '5aoj',
#  '5e2l',
#  '5mnr',
#  '3arq',
#  '1iih',
#  '3uod',
#  '1fzj',
#  '6f20',
#  '2wzm',
#  '3n76',
#  '5kly',
#  '2qd7',
#  '5nxi',
#  '3kjd',
#  '5vcz',
#  '2avm',
#  '2pwc',
#  '4b2l',
#  '5j41',
#  '2w66',
#  '3bra',
#  '2vuk',
#  '6b4u',
#  '2fqo',
#  '4buq',
#  '3mdz',
#  '4cp7',
#  '4lko',
#  '1jeu',
#  '5upz',
#  '3bl1',
#  '4jkw',
#  '2h4n',
#  '4wop',
#  '6h29',
#  '5m77',
#  '5hjq',
#  '2f81',
#  '3mxd',
#  '2qwc',
#  '3nyx',
#  '3t3c',
#  '1t31',
#  '4bah',
#  '1pzp',
#  '6czc',
#  '1x8t',
#  '4f2w',
#  '5ihh',
#  '3lpp',
#  '5e28',
#  '5os5',
#  '5ljt',
#  '5m7s',
#  '5w44',
#  '4lm0',
#  '2zkj',
#  '2zcr',
#  '5cc2',
#  '4mc9',
#  '2boh',
#  '5h8e',
#  '4u0w',
#  '1ppk',
#  '5yyf',
#  '2vwn',
#  '3zze',
#  '1okl',
#  '5j8m',
#  '4ivc',
#  '4uj2',
#  '2e7f',
#  '4baq',
#  '3rt8',
#  '4ysl',
#  '4j44',
#  '4a7i',
#  '3cyz',
#  '1b05',
#  '2wl0',
#  '2e27',
#  '3g0w',
# ...

# %%
import pandas as pd
import numpy as np

# %%
test_data = []
for l in l2:
    if l not in l1:
        test_data.append(l)
df = pd.DataFrame(test_data, columns=['name'])
df.head(20)
# Out:
#     name
# 0   6as8
# 1   6eeb
# 2   6dys
# 3   5zg1
# 4   6aro
# 5   6q4g
# 6   6eq5
# 7   6i17
# 8   6n7a
# 9   6aox
# 10  6g29
# 11  6qi7
# 12  6s57
# 13  6j0g
# 14  6plf
# 15  6fag
# 16  6md8
# 17  6otg
# 18  6pga
# 19  6d16
